# %% [markdown]
# # АВС - анализ

# %% [markdown]
# # 🎈🍾 🎉
#
#
#
#
#
# Вы работаете в крупном онлайн-магазине, который реализует товары «всё для праздников». Вам необходимо провести ABC-анализ и выявить наиболее важные товары на основе объемов продаж и популярности. Эта информация составит план закупок на весь следующий год.

# %% [markdown]
# **ABC-анализ** позволяет определить наиболее важные ресурсы компании на основе объемов продаж и прибыли.
#
# В основе ABC-анализа лежит __«Принцип Парето»: 20% ресурсов приносят 80% прибыли__. Именно этот вид анализа позволяет выделить те самые  группы товаров, ресурсов, клиентов, поставщиков и т. п., которые и приносят компании основную прибыль.

# %% [markdown]
# __Задача анализа разделить товары на группы по принципу:__
#
# - А — наиболее ценные, 20% — ассортимента (номенклатура); 80% — продаж
# - В — промежуточные, 30% — ассортимента; 15% — продаж
# - С — наименее ценные, 50% — ассортимента; 5% — продаж

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Сохраните все данные из таблицы `products` из PostgreSQL в дата-фрейм `products` и подготовьте данные к анализу.
#
# 1. Подгрузите данные для подключения
# 2. Подключите нужную библиотеку для работы с PostgreSQL
# 3. Создайте соединение с БД
# 4. Создайте запрос и выгрузите все данные из таблицы `products`
# 5. Положите данные в дата-фрейм `products`
# 6. Приведите данные к удобному типу: числа к числовому типу, идентификаторы — к текстовому

# %%
from postgresql_secret1 import pg_secret

# %%
import psycopg2

connection = psycopg2.connect(
                             database=pg_secret['db_name'],
                             user=pg_secret['db_user'],
                             password=pg_secret['db_password'],
                             host=pg_secret['db_host'],
                             port=pg_secret['db_port'],
                             )# создай соединение

cursor = connection.cursor()# заведи курсор, чтобы делать запросы в базу

# %%
import pandas as pd

query = """SELECT * 
           FROM products"""# напиши запрос, твоих знаний SQL точно хватит

cursor.execute(query)

result = cursor.fetchall()

result
# Out:
# [(524025, '21232', 'STRAWBERRY CERAMIC TRINKET BOX', 72, Decimal('1.06')),
#  (524025, '85099C', 'JUMBO  BAG BAROQUE BLACK WHITE', 100, Decimal('1.65')),
#  (524025, '21231', 'SWEETHEART CERAMIC TRINKET BOX', 72, Decimal('1.06')),
#  (524025, '47570B', 'TEA TIME TABLE CLOTH', 50, Decimal('8.49')),
#  (524025, '20685', 'DOORMAT RED RETROSPOT', 10, Decimal('6.75')),
#  (524025, '20718', 'RED SPOTTY SHOPPER BAG', 100, Decimal('1.06')),
#  (524025, '85150', 'LADIES & GENTLEMEN METAL SIGN', 48, Decimal('2.10')),
#  (524025, '22804', 'CANDLEHOLDER PINK HANGING HEART', 64, Decimal('2.55')),
#  (524026, '47559B', 'TEA TIME OVEN GLOVE', 100, Decimal('1.06')),
#  (524026, '21154', 'RED RETROSPOT OVEN GLOVE ', 200, Decimal('1.06')),
#  (524026, '47599A', 'PINK PARTY BAGS', 100, Decimal('1.69')),
#  (524027, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 672, Decimal('0.42')),
#  (524028, '85049E', 'SCANDINAVIAN REDS RIBBONS', 1, Decimal('1.25')),
#  (524028, '22082', 'RIBBON REEL STRIPES DESIGN ', 1, Decimal('1.65')),
#  (524028, '90129C', 'GREEN GLASS TASSLE BAG CHARM', 16, Decimal('2.95')),
#  (524028, '72815', '3 WICK CHRISTMAS BRIAR CANDLE ', 12, Decimal('3.75')),
#  (524028, '22121', 'NOEL WOODEN BLOCK LETTERS ', 12, Decimal('5.45')),
#  (524028, '21754', 'HOME BUILDING BLOCK WORD', 4, Decimal('5.95')),
#  (524028, '22457', 'NATURAL SLATE HEART CHALKBOARD ', 12, Decimal('2.95')),
#  (524028, '22470', 'HEART OF WICKER LARGE', 10, Decimal('2.95')),
#  (524028, '22469', 'HEART OF WICKER SMALL', 6, Decimal('1.65')),
#  (524028, '79190B', 'RETRO PLASTIC POLKA TRAY', 1, Decimal('0.42')),
#  (524028, '21986', 'PACK OF 12 PINK POLKADOT TISSUES', 12, Decimal('0.29')),
#  (524028, '22563', 'HAPPY STENCIL CRAFT', 2, Decimal('1.25')),
#  (524028, '22597', 'CHRISTMAS MUSICAL ZINC HEART ', 1, Decimal('0.85')),
#  (524028, '22139', 'RETROSPOT TEA SET CERAMIC 11 PC ', 2, Decimal('4.95')),
#  (524028, '22597', 'CHRISTMAS MUSICAL ZINC HEART ', 3, Decimal('0.85')),
#  (524028, '48188', 'DOORMAT WELCOME PUPPIES', 1, Decimal('7.95')),
#  (524028, '22513', 'DOORSTOP FOOTBALL DESIGN', 1, Decimal('3.75')),
#  (524028, '22594', 'CHRISTMAS GINGHAM TREE', 1, Decimal('0.85')),
#  (524028, '22333', 'RETROSPOT PARTY BAG + STICKER SET', 1, Decimal('1.65')),
#  (524028, '21221', 'SET/4 BADGES CUTE CREATURES', 2, Decimal('1.25')),
#  (524028, '84827', 'ASS DES PHONE SPONGE CRAFT STICKER', 7, Decimal('0.65')),
#  (524028, '22669', 'RED BABY BUNTING ', 3, Decimal('2.95')),
#  (524028, '21055', 'TOOL BOX SOFT TOY ', 1, Decimal('8.95')),
#  (524028, '20966', 'SANDWICH BATH SPONGE', 4, Decimal('1.25')),
#  (524028, '22593', 'CHRISTMAS GINGHAM STAR', 3, Decimal('0.85')),
#  (524028, '84839', 'SWEETHEART KEY CABINET', 1, Decimal('6.75')),
#  (524028, '22170', 'PICTURE FRAME WOOD TRIPLE PORTRAIT', 1, Decimal('6.75')),
#  (524028, '20718', 'RED RETROSPOT SHOPPER BAG', 1, Decimal('1.25')),
#  (524038, '48185', 'DOORMAT FAIRY CAKE', 2, Decimal('7.95')),
#  (524038, '21524', 'DOORMAT SPOTTY HOME SWEET HOME', 2, Decimal('7.95')),
#  (524038, '22366', 'DOORMAT AIRMAIL ', 2, Decimal('7.95')),
#  (524038, '22065', 'CHRISTMAS PUDDING TRINKET POT ', 12, Decimal('1.45')),
#  (524038, '21098', 'CHRISTMAS TOILET ROLL', 12, Decimal('1.25')),
#  (524038, '20685', 'DOORMAT RED SPOT', 2, Decimal('7.95')),
#  (524038, '22737', 'RIBBON REEL CHRISTMAS PRESENT ', 10, Decimal('1.65')),
#  (524038, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 48, Decimal('0.55')),
#  (524038, '22945', 'CHRISTMAS METAL TAGS ASSORTED ', 12, Decimal('0.85')),
#  (524038, '22950', '36 DOILIES VINTAGE CHRISTMAS', 12, Decimal('1.45')),
#  (524038, '22739', 'RIBBON REEL, XMAS SOCK/BAUBLE', 10, Decimal('1.65')),
#  (524038, '22738', 'RIBBON REEL SNOWY VILLAGE', 10, Decimal('1.65')),
#  (524038, '22689', 'DOORMAT MERRY CHRISTMAS RED ', 2, Decimal('7.95')),
#  (524038, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 6, Decimal('2.95')),
#  (524038, '22731', '3D STICKERS CHRISTMAS STAMPS', 20, Decimal('1.25')),
#  (524038, '22732', '3D STICKERS VINTAGE CHRISTMAS', 20, Decimal('1.25')),
#  (524038, '21164', 'HOME SWEET HOME METAL SIGN ', 6, Decimal('2.95')),
#  (524038, '22084', 'PAPER CHAIN KIT EMPIRE', 6, Decimal('2.95')),
#  (524038, '21875', 'KINGS CHOICE MUG', 12, Decimal('1.25')),
#  (524038, '21791', 'VINTAGE HEADS AND TAILS CARD GAME ', 24, Decimal('1.25')),
#  (524038, '22619', 'SET OF 6 SOLDIER SKITTLES', 4, Decimal('3.75')),
#  (524038, '22616', 'PACK OF 12 LONDON TISSUES ', 24, Decimal('0.29')),
#  (524038, '20724', 'RED SPOTTY CHARLOTTE BAG', 10, Decimal('0.85')),
#  (524038, '21790', 'VINTAGE SNAP CARDS', 24, Decimal('0.85')),
#  (524038, '85099B', 'JUMBO BAG RED RETROSPOT', 10, Decimal('1.95')),
#  (524038, '21832', 'CHOCOLATE CALCULATOR', 12, Decimal('1.65')),
#  (524038, '22623', 'BOX OF VINTAGE JIGSAW BLOCKS ', 3, Decimal('4.95')),
#  (524038, '22710', 'WRAP I LOVE LONDON ', 25, Decimal('0.42')),
#  (524038, '21877', 'HOME SWEET HOME MUG', 12, Decimal('1.25')),
#  (524038, '22329', 'ROUND CONTAINER SET OF 5 RETROSPOT', 6, Decimal('1.65')),
#  (524038, '21531', 'RED RETROSPOT SUGAR JAM BOWL', 6, Decimal('2.55')),
#  (524038, '21535', 'RED RETROSPOT SMALL MILK JUG', 6, Decimal('2.55')),
#  (524038, '21533', 'RETRO SPOT LARGE MILK JUG', 3, Decimal('4.95')),
#  (524038, '21539', 'RED RETROSPOT BUTTER DISH', 3, Decimal('4.95')),
#  (524038, '21527', 'RED RETROSPOT TRADITIONAL TEAPOT ', 2, Decimal('7.95')),
#  (524038, '21537', 'RED RETROSPOT PUDDING BOWL', 4, Decimal('4.25')),
#  (524038, '22911', 'PAPER CHAIN KIT LONDON', 6, Decimal('2.95')),
#  (524038, '22900', ' SET 2 TEA TOWELS I LOVE LONDON ', 6, Decimal('2.95')),
#  (524038, '22902', 'TOTE BAG I LOVE LONDON', 12, Decimal('2.10')),
#  (524038, '22644', 'CERAMIC CHERRY CAKE MONEY BANK', 12, Decimal('1.45')),
#  (524038, '21212', 'PACK OF 72 RETRO SPOT CAKE CASES', 24, Decimal('0.55')),
#  (524038, '21035', 'SET/2 RED SPOTTY TEA TOWELS ', 6, Decimal('2.95')),
#  (524038, '21755', 'LOVE BUILDING BLOCK WORD', 6, Decimal('5.95')),
#  (524038, '22434', 'BALLOON PUMP WITH 10 BALLOONS', 8, Decimal('1.95')),
#  (524077, '21212', 'PACK OF 72 RETRO SPOT CAKE CASES', 24, Decimal('0.55')),
#  (524077, '21080', 'SET/20 RED SPOTTY PAPER NAPKINS ', 48, Decimal('0.85')),
#  (524077, '22536', 'MAGIC DRAWING SLATE PURDEY', 24, Decimal('0.42')),
#  (524077, '22533', 'MAGIC DRAWING SLATE BAKE A CAKE ', 24, Decimal('0.42')),
#  (524077, '22354', 'RETROSPOT PADDED SEAT CUSHION', 60, Decimal('3.39')),
#  (524077, '85031B', 'BLOSSOM IMAGES SCRAP BOOK SET', 24, Decimal('1.25')),
#  (524077, '17091A', 'LAVENDER INCENSE IN TIN', 36, Decimal('0.38')),
#  (524077, '20914', 'SET/5 RED SPOTTY LID GLASS BOWLS', 12, Decimal('2.95')),
#  (524077, '22378', 'WALL TIDY RETROSPOT ', 10, Decimal('2.10')),
#  (524077, '47566B', 'TEA TIME PARTY BUNTING', 5, Decimal('4.65')),
#  (524077, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 18, Decimal('2.95')),
#  (524077, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 24, Decimal('0.55')),
#  (524077, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 24, Decimal('0.85')),
#  (524077, '22950', '36 DOILIES VINTAGE CHRISTMAS', 24, Decimal('1.45')),
#  (524077, '22065', 'CHRISTMAS PUDDING TRINKET POT ', 12, Decimal('1.45')),
#  (524077, '22571', 'ROCKING HORSE RED CHRISTMAS ', 12, Decimal('0.85')),
#  (524077, '22596', 'CHRISTMAS STAR WISH LIST CHALKBOARD', 12, Decimal('0.85')),
#  (524077, '21915', 'RED  HARMONICA IN BOX ', 12, Decimal('1.25')),
#  (524077, '21914', 'BLUE HARMONICA IN BOX ', 12, Decimal('1.25')),
#  (524077, '22199', 'FRYING PAN RED POLKADOT ', 4, Decimal('4.25')),
#  (524079, '22340', 'NOEL GARLAND PAINTED ZINC ', 12, Decimal('1.65')),
#  (524079, '22505', 'MEMO BOARD COTTAGE DESIGN', 8, Decimal('4.95')),
#  (524079, '21363', 'HOME SMALL WOOD LETTERS', 6, Decimal('4.95')),
#  (524079, '21056', "DOCTOR'S BAG SOFT TOY", 3, Decimal('8.95')),
#  (524079, '20749', 'ASSORTED COLOUR MINI CASES', 12, Decimal('6.35')),
#  (524079, '22659', 'LUNCH BOX I LOVE LONDON', 12, Decimal('1.95')),
#  (524079, '22378', 'WALL TIDY RETROSPOT ', 5, Decimal('2.10')),
#  (524079, '22423', 'REGENCY CAKESTAND 3 TIER', 16, Decimal('10.95')),
#  (524079, '22634', 'CHILDS BREAKFAST SET SPACEBOY ', 8, Decimal('8.50')),
#  (524079, '47566', 'PARTY BUNTING', 20, Decimal('4.65')),
#  (524079, '21116', 'OWL DOORSTOP', 3, Decimal('4.95')),
#  (524079, '84945', 'MULTI COLOUR SILVER T-LIGHT HOLDER', 12, Decimal('0.85')),
#  (524079, '22469', 'HEART OF WICKER SMALL', 12, Decimal('1.65')),
#  (524079, '22169', 'FAMILY ALBUM WHITE PICTURE FRAME', 8, Decimal('7.65')),
#  (524091, '22748', "POPPY'S PLAYHOUSE KITCHEN", 6, Decimal('2.10')),
#  (524091, '22746', "POPPY'S PLAYHOUSE LIVINGROOM ", 6, Decimal('2.10')),
#  (524091, '21888', 'BINGO SET', 8, Decimal('3.75')),
#  (524091, '22584', 'PACK OF 6 PANNETONE GIFT BOXES', 12, Decimal('2.55')),
#  (524091, '22585', 'PACK OF 6 BIRDY GIFT TAGS', 12, Decimal('1.25')),
#  (524091, '22582', 'PACK OF 6 SWEETIE GIFT BOXES', 12, Decimal('2.55')),
#  (524091, '22423', 'REGENCY CAKESTAND 3 TIER', 4, Decimal('12.75')),
#  (524091, '21231', 'SWEETHEART CERAMIC TRINKET BOX', 12, Decimal('1.25')),
#  (524091, '21232', 'STRAWBERRY CERAMIC TRINKET BOX', 12, Decimal('1.25')),
#  (524091, '22457', 'NATURAL SLATE HEART CHALKBOARD ', 6, Decimal('2.95')),
#  (524091, '22810', 'SET OF 6 T-LIGHTS SNOWMEN', 12, Decimal('2.95')),
#  (524091, '22809', 'SET OF 6 T-LIGHTS SANTA', 12, Decimal('2.95')),
#  (524091, '35970', 'ZINC FOLKART SLEIGH BELLS', 12, Decimal('1.69')),
#  (524091, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 12, Decimal('2.95')),
#  (524091, '22835', 'HOT WATER BOTTLE I AM SO POORLY', 4, Decimal('4.65')),
#  (524091, '22375', 'AIRLINE BAG VINTAGE JET SET BROWN', 4, Decimal('4.25')),
#  (524091, '22372', 'AIRLINE BAG VINTAGE WORLD CHAMPION ', 4, Decimal('4.25')),
#  (524091, '22374', 'AIRLINE BAG VINTAGE JET SET RED', 4, Decimal('4.25')),
#  (524091, '22376', 'AIRLINE BAG VINTAGE JET SET WHITE', 4, Decimal('4.25')),
#  (524091, '84991', '60 TEATIME FAIRY CAKE CASES', 24, Decimal('0.55')),
#  (524091, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 24, Decimal('0.55')),
#  (524091, '21213', 'PACK OF 72 SKULL CAKE CASES', 24, Decimal('0.55')),
#  (524091, '21212', 'PACK OF 72 RETRO SPOT CAKE CASES', 24, Decimal('0.55')),
#  (524092, '22197', 'SMALL POPCORN HOLDER', 24, Decimal('0.85')),
#  (524092, '22804', 'CANDLEHOLDER PINK HANGING HEART', 32, Decimal('2.55')),
#  (524092, '22345', 'PARTY PIZZA DISH BLUE RETROSPOT', 12, Decimal('0.85')),
#  (524092, '22343', 'PARTY PIZZA DISH RED RETROSPOT', 12, Decimal('0.85')),
#  (524092, '22344', 'PARTY PIZZA DISH PINK RETROSPOT', 12, Decimal('0.85')),
#  (524092, '85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', 32, Decimal('2.55')),
#  (524092, '84755', 'COLOUR GLASS T-LIGHT HOLDER HANGING', 32, Decimal('0.65')),
#  (524092, '22727', 'ALARM CLOCK BAKELIKE RED ', 4, Decimal('3.75')),
#  (524092, '22728', 'ALARM CLOCK BAKELIKE PINK', 4, Decimal('3.75')),
#  (524092, '22730', 'ALARM CLOCK BAKELIKE IVORY', 4, Decimal('3.75')),
#  (524092, '22698', 'TEACUP AND SAUCER REGENCY PINK', 12, Decimal('2.95')),
#  (524092, '22699', 'TEACUP AND SAUCER REGENCY ROSES', 12, Decimal('2.95')),
#  (524092, '22697', 'TEACUP AND SAUCER REGENCY GREEN', 12, Decimal('2.95')),
#  (524092, '22423', 'REGENCY CAKESTAND 3 TIER', 8, Decimal('12.75')),
#  (524092, '22626', 'BLACK KITCHEN SCALES', 4, Decimal('8.50')),
#  (524092, '22624', 'IVORY KITCHEN SCALES', 6, Decimal('8.50')),
#  (524092, '22627', 'MINT KITCHEN SCALES', 6, Decimal('8.50')),
#  (524092, '22192', 'BLUE DINER WALL CLOCK', 2, Decimal('8.50')),
#  (524092, '22191', 'IVORY DINER WALL CLOCK', 2, Decimal('8.50')),
#  (524092, '75049L', 'LARGE CIRCULAR MIRROR MOBILE', 192, Decimal('0.85')),
#  (524092, '22186', 'RED STAR CARD HOLDER', 6, Decimal('2.95')),
#  (524092, '21789', 'KIDS RAIN MAC PINK', 24, Decimal('0.85')),
#  (524092, '21788', 'KIDS RAIN MAC BLUE', 24, Decimal('0.85')),
#  (524092, '22835', 'HOT WATER BOTTLE I AM SO POORLY', 4, Decimal('4.65')),
#  (524092, '22111', 'SCOTTIE DOG HOT WATER BOTTLE', 3, Decimal('4.95')),
#  (524092, '22112', 'CHOCOLATE HOT WATER BOTTLE', 3, Decimal('4.95')),
#  (524092, '21485', 'RED SPOT HEART HOT WATER BOTTLE', 3, Decimal('4.95')),
#  (524092, '21917', 'SET 12 KIDS  WHITE CHALK STICKS', 24, Decimal('0.42')),
#  (524092, '22198', 'LARGE POPCORN HOLDER ', 24, Decimal('1.65')),
#  (524093, '21912', 'VINTAGE SNAKES & LADDERS', 4, Decimal('3.75')),
#  (524093, '20983', '12 PENCILS TALL TUBE RED SPOTTY', 12, Decimal('0.85')),
#  (524093, '16156S', 'WRAP PINK FAIRY CAKES ', 25, Decimal('0.42')),
#  (524093, '84029G', 'KNITTED UNION FLAG HOT WATER BOTTLE', 4, Decimal('3.75')),
#  (524093, '21488', 'RED WHITE SCARF  HOT WATER BOTTLE', 4, Decimal('3.95')),
#  (524093, '21080', 'SET/20 RED SPOTTY PAPER NAPKINS ', 12, Decimal('0.85')),
#  (524093, '47566', 'PARTY BUNTING', 5, Decimal('4.65')),
#  (524093, '21733', 'RED HANGING HEART T-LIGHT HOLDER', 6, Decimal('2.95')),
#  (524093, '85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', 12, Decimal('2.95')),
#  (524093, '22187', 'GREEN CHRISTMAS TREE CARD HOLDER', 4, Decimal('4.25')),
#  (524093, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 24, Decimal('0.55')),
#  (524093, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 12, Decimal('0.85')),
#  (524093, '85049A', 'TRADITIONAL CHRISTMAS RIBBONS', 12, Decimal('1.25')),
#  (524093, '22571', 'ROCKING HORSE RED CHRISTMAS ', 12, Decimal('0.85')),
#  (524093, '22579', 'WOODEN TREE CHRISTMAS SCANDINAVIAN', 12, Decimal('0.85')),
#  (524093, '22577', 'WOODEN HEART CHRISTMAS SCANDINAVIAN', 12, Decimal('0.85')),
#  (524093, '22578', 'WOODEN STAR CHRISTMAS SCANDINAVIAN', 12, Decimal('0.85')),
#  (524093, '22601', 'CHRISTMAS RETROSPOT ANGEL WOOD', 12, Decimal('0.85')),
#  (524093, '22595', 'CHRISTMAS GINGHAM HEART', 12, Decimal('0.85')),
#  (524093, '22594', 'CHRISTMAS GINGHAM TREE', 12, Decimal('0.85')),
#  (524093, '22619', 'SET OF 6 SOLDIER SKITTLES', 8, Decimal('3.75')),
#  (524093, '22321', 'BIRD DECORATION RED SPOT', 12, Decimal('0.85')),
#  (524093, '21790', 'VINTAGE SNAP CARDS', 12, Decimal('0.85')),
#  (524093, '84520B', 'PACK 20 ENGLISH ROSE PAPER NAPKINS', 12, Decimal('0.85')),
#  (524093, '21948', 'SET OF 6 CAKE CHOPSTICKS', 12, Decimal('1.25')),
#  (524094, '35832', 'WOOLLY HAT SOCK GLOVE ADVENT STRING', 12, Decimal('2.95')),
#  (524094, '22669', 'RED BABY BUNTING ', 10, Decimal('2.95')),
#  (524094, '22295', 'HEART FILIGREE DOVE LARGE', 24, Decimal('1.65')),
#  (524094, '22294', 'HEART FILIGREE DOVE  SMALL', 24, Decimal('1.25')),
#  (524094, '21491', 'SET OF THREE VINTAGE GIFT WRAPS', 48, Decimal('1.65')),
#  (524094, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 40, Decimal('2.55')),
#  (524094, '22959', 'WRAP CHRISTMAS VILLAGE', 25, Decimal('0.42')),
#  (524094, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 24, Decimal('0.55')),
#  (524094, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 12, Decimal('0.85')),
#  (524094, '22086', "PAPER CHAIN KIT 50'S CHRISTMAS ", 40, Decimal('2.55')),
#  (524094, '84946', 'ANTIQUE SILVER TEA GLASS ETCHED', 72, Decimal('1.06')),
#  (524094,
#   '84347',
#   'ROTATING SILVER ANGELS T-LIGHT HLDR',
#   120,
#   Decimal('2.10')),
#  (524094, '22090', 'PAPER BUNTING RETRO SPOTS', 40, Decimal('2.55')),
#  (524094, '22567', '20 DOLLY PEGS RETROSPOT', 48, Decimal('1.06')),
#  (524094, '22727', 'ALARM CLOCK BAKELIKE RED ', 4, Decimal('3.75')),
#  (524094, '22728', 'ALARM CLOCK BAKELIKE PINK', 4, Decimal('3.75')),
#  (524094, '22726', 'ALARM CLOCK BAKELIKE GREEN', 4, Decimal('3.75')),
#  (524094, '21733', 'RED HANGING HEART T-LIGHT HOLDER', 6, Decimal('2.95')),
#  (524095, '47590A', 'BLUE HAPPY BIRTHDAY BUNTING', 50, Decimal('4.65')),
#  (524096, '22713', 'CARD I LOVE LONDON ', 72, Decimal('0.36')),
#  (524096, '22716', 'CARD CIRCUS PARADE', 72, Decimal('0.36')),
#  (524096, '79321', 'CHILLI LIGHTS', 120, Decimal('4.25')),
#  (524096, '16048', 'TEATIME ROUND PENCIL SHARPENER ', 768, Decimal('0.12')),
#  (524096, '21263', 'GREEN GOOSE FEATHER TREE 60CM', 72, Decimal('1.95')),
#  (524096, '21265', 'PINK GOOSE FEATHER TREE 60CM', 72, Decimal('1.95')),
#  (524097, '22088', 'PAPER BUNTING COLOURED LACE', 40, Decimal('2.55')),
#  (524097, '22089', 'PAPER BUNTING VINTAGE PAISLEY', 40, Decimal('2.55')),
#  (524097, '22090', 'PAPER BUNTING RETRO SPOTS', 40, Decimal('2.55')),
#  (524097, '47566', 'PARTY BUNTING', 150, Decimal('3.75')),
#  (524098, '22145', 'CHRISTMAS CRAFT HEART STOCKING ', 6, Decimal('2.10')),
#  (524098, '22812', 'PACK 3 BOXES CHRISTMAS PANNETONE', 36, Decimal('1.95')),
#  (524098, '22639', 'SET OF 4 NAPKIN CHARMS HEARTS', 6, Decimal('2.55')),
#  (524098, '22604', 'SET OF 4 NAPKIN CHARMS CUTLERY', 6, Decimal('2.55')),
#  (524098, '22642', 'SET OF 4 NAPKIN CHARMS STARS   ', 6, Decimal('2.55')),
#  (524098, '84879', 'ASSORTED COLOUR BIRD ORNAMENT', 48, Decimal('1.69')),
#  (524098, '22627', 'MINT KITCHEN SCALES', 2, Decimal('8.50')),
#  (524098, '20914', 'SET/5 RED SPOTTY LID GLASS BOWLS', 6, Decimal('2.95')),
#  (524098, '21217', 'RED SPOTTY ROUND CAKE TINS', 4, Decimal('9.95')),
#  (524098, '22423', 'REGENCY CAKESTAND 3 TIER', 2, Decimal('12.75')),
#  (524098, '22584', 'PACK OF 6 PANNETONE GIFT BOXES', 6, Decimal('2.55')),
#  (524098, '22585', 'PACK OF 6 BIRDY GIFT TAGS', 12, Decimal('1.25')),
#  (524098, '22635', 'CHILDS BREAKFAST SET DOLLY GIRL ', 2, Decimal('9.95')),
#  (524098, '22634', 'CHILDS BREAKFAST SET SPACEBOY ', 2, Decimal('9.95')),
#  (524098, '22382', 'LUNCH BAG SPACEBOY DESIGN ', 10, Decimal('1.65')),
#  (524098, '20725', 'LUNCH BAG RED SPOTTY', 10, Decimal('1.65')),
#  (524098, '22384', 'LUNCH BAG PINK RETROSPOT', 10, Decimal('1.65')),
#  (524098, '22662', 'LUNCH BAG DOLLY GIRL DESIGN', 10, Decimal('1.65')),
#  (524098, '20727', 'LUNCH BAG  BLACK SKULL.', 10, Decimal('1.65')),
#  (524098, '22383', 'LUNCH BAG SUKI  DESIGN ', 10, Decimal('1.65')),
#  (524098, '20728', 'LUNCH BAG CARS BLUE', 10, Decimal('1.65')),
#  (524098, '20726', 'LUNCH BAG WOODLAND', 10, Decimal('1.65')),
#  (524098, '22580', 'ADVENT CALENDAR GINGHAM SACK', 12, Decimal('5.95')),
#  (524098, '22599', 'CHRISTMAS MUSICAL ZINC STAR', 72, Decimal('0.72')),
#  (524098, '35400', 'WOODEN BOX ADVENT CALENDAR ', 2, Decimal('8.95')),
#  (524098, '85048', '15CM CHRISTMAS GLASS BALL 20 LIGHTS', 24, Decimal('6.95')),
#  (524098, '21821', 'GLITTER STAR GARLAND WITH BELLS ', 12, Decimal('3.75')),
#  (524098, '21820', 'GLITTER HEART GARLAND WITH BELLS ', 12, Decimal('3.75')),
#  (524098, '21822', 'GLITTER CHRISTMAS TREE WITH BELLS', 24, Decimal('1.95')),
#  (524098, '21143', 'ANTIQUE GLASS HEART DECORATION ', 36, Decimal('1.95')),
#  (524098, '21146', 'ANTIQUE GLASS RIDGED HANGING BALL', 36, Decimal('1.95')),
#  (524098, '22086', "PAPER CHAIN KIT 50'S CHRISTMAS ", 12, Decimal('2.95')),
#  (524098, '22809', 'SET OF 6 T-LIGHTS SANTA', 12, Decimal('2.95')),
#  (524098, '47590B', 'PINK HAPPY BIRTHDAY BUNTING', 3, Decimal('5.45')),
#  (524098, '47590A', 'BLUE HAPPY BIRTHDAY BUNTING', 3, Decimal('5.45')),
#  (524098, '21124', 'SET/10 BLUE SPOTTY PARTY CANDLES', 24, Decimal('1.25')),
#  (524098, '21123', 'SET/10 IVORY SPOTTY PARTY CANDLES', 24, Decimal('1.25')),
#  (524098, '21122', 'SET/10 PINK SPOTTY PARTY CANDLES', 24, Decimal('1.25')),
#  (524098, '21121', 'SET/10 RED SPOTTY PARTY CANDLES', 24, Decimal('1.25')),
#  (524098, '22085', 'PAPER CHAIN KIT SKULLS ', 6, Decimal('2.95')),
#  (524098, '22334', 'DINOSAUR PARTY BAG + STICKER SET', 8, Decimal('1.65')),
#  (524098, '22333', 'RETRO SPOT PARTY BAG + STICKER SET', 8, Decimal('1.65')),
#  (524098, '22332', 'SKULLS PARTY BAG + STICKER SET', 8, Decimal('1.65')),
#  (524098, '22331', 'WOODLAND PARTY BAG + STICKER SET', 8, Decimal('1.65')),
#  (524098, '47599B', 'BLUE PARTY BAGS ', 6, Decimal('2.10')),
#  (524098, '47599A', 'PINK PARTY BAGS', 6, Decimal('2.10')),
#  (524098, '85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', 32, Decimal('2.55')),
#  (524098, '21733', 'RED HANGING HEART T-LIGHT HOLDER', 32, Decimal('2.55')),
#  (524098, '21989', 'PACK OF 20 SKULL PAPER NAPKINS', 12, Decimal('0.85')),
#  (524098, '21987', 'PACK OF 6 SKULL PAPER CUPS', 12, Decimal('0.65')),
#  (524098, '21988', 'PACK OF 6 SKULL PAPER PLATES', 12, Decimal('0.85')),
#  (524098, '21086', 'SET/6 RED SPOTTY PAPER CUPS', 12, Decimal('0.65')),
#  (524098, '21094', 'SET/6 RED SPOTTY PAPER PLATES', 12, Decimal('0.85')),
#  (524098, '22613', 'PACK OF 20 SPACEBOY NAPKINS', 12, Decimal('0.85')),
#  (524098, '21781', 'MA CAMPAGNE CUTLERY BOX', 2, Decimal('14.95')),
#  (524098, '22945', 'CHRISTMAS METAL TAGS ASSORTED ', 36, Decimal('0.85')),
#  (524098, '22598', 'CHRISTMAS MUSICAL ZINC TREE', 72, Decimal('0.72')),
#  (524098, '22597', 'CHRISTMAS MUSICAL ZINC HEART ', 72, Decimal('0.72')),
#  (524098, '22594', 'CHRISTMAS GINGHAM TREE', 48, Decimal('0.85')),
#  (524098, '22595', 'CHRISTMAS GINGHAM HEART', 48, Decimal('0.85')),
#  (524098, '22593', 'CHRISTMAS GINGHAM STAR', 48, Decimal('0.85')),
#  (524098, '22572', 'ROCKING HORSE GREEN CHRISTMAS ', 24, Decimal('0.85')),
#  (524098, '22571', 'ROCKING HORSE RED CHRISTMAS ', 24, Decimal('0.85')),
#  (524098, '22579', 'WOODEN TREE CHRISTMAS SCANDINAVIAN', 24, Decimal('0.85')),
#  (524098, '22581', 'WOOD STOCKING CHRISTMAS SCANDISPOT', 24, Decimal('0.85')),
#  (524098, '22578', 'WOODEN STAR CHRISTMAS SCANDINAVIAN', 24, Decimal('0.85')),
#  (524098, '22577', 'WOODEN HEART CHRISTMAS SCANDINAVIAN', 24, Decimal('0.85')),
#  (524098, '22470', 'HEART OF WICKER LARGE', 18, Decimal('2.95')),
#  (524098, '22694', 'WICKER STAR ', 12, Decimal('2.10')),
#  (524098, '22946', 'WOODEN ADVENT CALENDAR CREAM', 2, Decimal('16.95')),
#  (524098, '22947', 'WOODEN ADVENT CALENDAR RED', 2, Decimal('16.95')),
#  (524099, '22312', 'OFFICE MUG WARMER POLKADOT', 3, Decimal('2.95')),
#  (524099, '22112', 'CHOCOLATE HOT WATER BOTTLE', 6, Decimal('4.95')),
#  (524099, '22114', 'HOT WATER BOTTLE TEA AND SYMPATHY', 3, Decimal('3.95')),
#  (524099, '22835', 'HOT WATER BOTTLE I AM SO POORLY', 3, Decimal('4.65')),
#  (524099, '84030E', 'ENGLISH ROSE HOT WATER BOTTLE', 3, Decimal('4.25')),
#  (524099, '21908', 'CHOCOLATE THIS WAY METAL SIGN', 3, Decimal('2.10')),
#  (524099, '82597', 'BOMBS AWAY METAL SIGN', 4, Decimal('2.10')),
#  (524099, '82599', "FANNY'S REST STOPMETAL SIGN", 1, Decimal('2.10')),
#  (524099, '22117', 'METAL SIGN HER DINNER IS SERVED ', 1, Decimal('2.95')),
#  (524099, '85152', 'HAND OVER THE CHOCOLATE   SIGN ', 6, Decimal('2.10')),
#  (524099, '85150', 'LADIES & GENTLEMEN METAL SIGN', 6, Decimal('2.55')),
#  (524099, '82600', 'NO SINGING METAL SIGN', 6, Decimal('2.10')),
#  (524099, '21904', 'HOUSE WRECKING METAL SIGN ', 4, Decimal('2.10')),
#  (524099, '22413', 'METAL SIGN TAKE IT OR LEAVE IT ', 6, Decimal('2.95')),
#  (524099, '21903', 'MAN FLU METAL SIGN', 6, Decimal('2.10')),
#  (524099, '22412', 'METAL SIGN NEIGHBOURHOOD WITCH ', 6, Decimal('2.10')),
#  (524099, '82578', 'KITCHEN METAL SIGN', 4, Decimal('0.55')),
#  (524099, '82581', 'TOILET METAL SIGN', 4, Decimal('0.55')),
#  (524099, '82580', 'BATHROOM METAL SIGN', 4, Decimal('0.55')),
#  (524099, '22671', 'FRENCH LAUNDRY SIGN BLUE METAL', 4, Decimal('1.65')),
#  (524099, '22674', 'FRENCH TOILET SIGN BLUE METAL', 4, Decimal('1.25')),
#  (524099, '22672', 'FRENCH BATHROOM SIGN BLUE METAL', 4, Decimal('1.65')),
#  (524099, '22675', 'FRENCH KITCHEN SIGN BLUE METAL', 3, Decimal('1.25')),
#  (524099, '22670', 'FRENCH WC SIGN BLUE METAL', 4, Decimal('1.25')),
#  (524099, '21169', "YOU'RE CONFUSING ME METAL SIGN ", 8, Decimal('1.69')),
#  (524099, '21172', 'PARTY METAL SIGN ', 6, Decimal('1.45')),
#  (524099, '82552', 'WASHROOM METAL SIGN', 4, Decimal('1.45')),
#  (524099, '82551', 'LAUNDRY 15C METAL SIGN', 4, Decimal('1.45')),
#  (524099, '21171', 'BATHROOM METAL SIGN ', 4, Decimal('1.45')),
#  (524099, '21166', 'COOK WITH WINE METAL SIGN ', 8, Decimal('1.95')),
#  (524099, '21905', 'MORE BUTTER METAL SIGN ', 6, Decimal('2.10')),
#  (524099, '21843', 'RED RETROSPOT CAKE STAND', 2, Decimal('10.95')),
#  (524099, '37500', 'TEA TIME TEAPOT IN GIFT BOX', 3, Decimal('9.95')),
#  (524099, '22567', '20 DOLLY PEGS RETROSPOT', 6, Decimal('1.25')),
#  (524099, '21874', 'GIN AND TONIC MUG', 6, Decimal('1.25')),
#  (524099, '21527', 'RED RETROSPOT TRADITIONAL TEAPOT ', 2, Decimal('7.95')),
#  (524099, '21870', 'I CAN ONLY PLEASE ONE PERSON MUG', 6, Decimal('1.25')),
#  (524099, '84692', 'BOX OF 24 COCKTAIL PARASOLS', 25, Decimal('0.42')),
#  (524099, '22752', 'SET 7 BABUSHKA NESTING BOXES', 3, Decimal('8.50')),
#  (524099, '22755', 'SMALL PURPLE BABUSHKA NOTEBOOK ', 24, Decimal('0.85')),
#  (524099, '22666', 'RECIPE BOX PANTRY YELLOW DESIGN', 3, Decimal('2.95')),
#  (524099, '22449', 'SILK PURSE BABUSHKA PINK', 4, Decimal('3.35')),
#  (524099, '22423', 'REGENCY CAKESTAND 3 TIER', 3, Decimal('12.75')),
#  (524099, '21947', 'SET OF 6 HEART CHOPSTICKS', 12, Decimal('1.25')),
#  (524099, '20966', 'SANDWICH BATH SPONGE', 10, Decimal('1.25')),
#  (524099, '22614', 'PACK OF 12 SPACEBOY TISSUES', 10, Decimal('0.29')),
#  (524099, '21982', 'PACK OF 12 SUKI TISSUES ', 36, Decimal('0.29')),
#  (524099, '21980', 'PACK OF 12 RED RETROSPOT TISSUES ', 10, Decimal('0.29')),
#  (524099, '72741', 'GRAND CHOCOLATECANDLE', 18, Decimal('1.45')),
#  (524099, '20961', 'STRAWBERRY BATH SPONGE ', 10, Decimal('1.25')),
#  (524099, '84849B', 'FAIRY SOAP SOAP HOLDER', 6, Decimal('1.69')),
#  (524099, '22834', 'HAND WARMER BABUSHKA DESIGN', 4, Decimal('2.10')),
#  (524099, '22866', 'HAND WARMER SCOTTY DOG DESIGN', 4, Decimal('2.10')),
#  (524099, '84991', '60 TEATIME FAIRY CAKE CASES', 5, Decimal('0.55')),
#  (524099, '15034', 'PAPER POCKET TRAVELING FAN ', 36, Decimal('0.14')),
#  (524099, '22851', 'SET 20 NAPKINS FAIRY CAKES DESIGN ', 6, Decimal('0.85')),
#  (524099, '22396', 'MAGNETS PACK OF 4 RETRO PHOTO', 12, Decimal('1.25')),
#  (524099, '22064', 'PINK DOUGHNUT TRINKET POT ', 6, Decimal('1.65')),
#  (524099, '22649', 'STRAWBERRY FAIRY CAKE TEAPOT', 2, Decimal('4.95')),
#  (524099, '21531', 'RED RETROSPOT SUGAR JAM BOWL', 3, Decimal('2.55')),
#  (524099, '21231', 'SWEETHEART CERAMIC TRINKET BOX', 6, Decimal('1.25')),
#  (524099, '37501', 'TEA TIME TEA SET IN GIFT BOX', 2, Decimal('6.95')),
#  (524099, '47579', 'TEA TIME BREAKFAST BASKET', 6, Decimal('2.10')),
#  (524099, '47559B', 'TEA TIME OVEN GLOVE', 6, Decimal('1.25')),
#  (524099, '47556B', 'TEA TIME TEA TOWELS ', 4, Decimal('2.95')),
#  (524099, '47567B', 'TEA TIME KITCHEN APRON', 6, Decimal('5.95')),
#  (524099, '22375', 'AIRLINE BAG VINTAGE JET SET BROWN', 3, Decimal('4.25')),
#  (524099, '22376', 'AIRLINE BAG VINTAGE JET SET WHITE', 3, Decimal('4.25')),
#  (524099, '22371', 'AIRLINE BAG VINTAGE TOKYO 78', 3, Decimal('4.25')),
#  (524099, '22470', 'HEART OF WICKER LARGE', 1, Decimal('2.95')),
#  (524099, '20754', 'RETROSPOT RED WASHING UP GLOVES', 6, Decimal('2.10')),
#  (524099, '22192', 'BLUE DINER WALL CLOCK', 4, Decimal('8.50')),
#  (524099, '22199', 'FRYING PAN RED RETROSPOT', 3, Decimal('4.25')),
#  (524099, '37448', 'CERAMIC CAKE DESIGN SPOTTED MUG', 4, Decimal('1.49')),
#  (524099, '21232', 'STRAWBERRY CERAMIC TRINKET BOX', 12, Decimal('1.25')),
#  (524099, '22645', 'CERAMIC HEART FAIRY CAKE MONEY BANK', 2, Decimal('1.45')),
#  (524099, '21906', 'PHARMACIE FIRST AID TIN', 2, Decimal('6.75')),
#  (524099, '21260', 'FIRST AID TIN', 3, Decimal('3.25')),
#  (524099, '22494', 'EMERGENCY FIRST AID TIN ', 6, Decimal('1.25')),
#  (524099, '22551', 'PLASTERS IN TIN SPACEBOY', 6, Decimal('1.65')),
#  (524099, '22557', 'PLASTERS IN TIN VINTAGE PAISLEY ', 8, Decimal('1.65')),
#  (524099, '21221', 'SET/4 BADGES CUTE CREATURES', 20, Decimal('1.25')),
#  (524099, '21219', 'SET/4 BADGES BALLOON GIRL', 20, Decimal('1.25')),
#  (524099, '21220', 'SET/4 BADGES DOGS', 20, Decimal('1.25')),
#  (524099, '85047', 'WHITE BEADED GARLAND STRING 20LIGHT', 4, Decimal('6.35')),
#  (524099, '22390', 'PAPERWEIGHT CHILDHOOD MEMORIES', 8, Decimal('2.55')),
#  (524099, '22511', 'RETROSPOT BABUSHKA DOORSTOP', 2, Decimal('3.75')),
#  (524099, '21028', 'NINJA RABBIT BLACK', 10, Decimal('1.25')),
#  (524099, '21031', 'SPACE CADET BLACK', 10, Decimal('1.25')),
#  (524099, '21027', 'NINJA RABBIT PINK', 10, Decimal('1.25')),
#  (524099, '21030', 'SPACE CADET RED', 10, Decimal('1.25')),
#  (524099, '21026', 'SPACE OWL', 10, Decimal('1.25')),
#  (524099, '20971', 'PINK BLUE FELT CRAFT TRINKET BOX', 6, Decimal('1.25')),
#  (524099, '22637', 'PIGGY BANK RETROSPOT ', 4, Decimal('2.55')),
#  (524099, '79321', 'CHILLI LIGHTS', 3, Decimal('4.95')),
#  (524099, '22468', 'BABUSHKA LIGHTS STRING OF 10', 3, Decimal('6.75')),
#  (524099, '22492', 'MINI PAINT SET VINTAGE ', 36, Decimal('0.65')),
#  (524099, '22491', 'PACK OF 12 COLOURED PENCILS', 12, Decimal('0.85')),
#  (524099, '22210', 'WOOD STAMP SET BEST WISHES', 8, Decimal('1.65')),
#  (524100, '22476', 'EMPIRE UNION JACK TV DINNER TRAY', 2, Decimal('4.95')),
#  (524100, '72802C', 'VANILLA SCENT CANDLE JEWELLED BOX', 6, Decimal('4.25')),
#  (524100, '22214', 'CANDLE PLATE LACE WHITE', 10, Decimal('2.55')),
#  (524100, '72807C', 'SET/3 VANILLA SCENTED CANDLE IN BOX', 3, Decimal('4.25')),
#  (524100, '84877A', 'PINK ROUND COMPACT MIRROR', 1, Decimal('3.75')),
#  (524100, '21877', 'HOME SWEET HOME MUG', 1, Decimal('1.25')),
#  (524100, '21875', 'KINGS CHOICE MUG', 1, Decimal('1.25')),
#  (524100, '22469', 'HEART OF WICKER SMALL', 1, Decimal('1.65')),
#  (524100, '22867', 'HAND WARMER BIRD DESIGN', 1, Decimal('2.10')),
#  (524100, '22476', 'EMPIRE UNION JACK TV DINNER TRAY', 1, Decimal('4.95')),
#  (524100, '21827', 'EIGHT PIECE CREEPY CRAWLIE SET', 1, Decimal('1.25')),
#  (524100, '21826', 'EIGHT PIECE DINOSAUR SET', 1, Decimal('1.25')),
#  (524100, '72802A', 'ROSE SCENT CANDLE IN JEWELLED BOX', 6, Decimal('4.25')),
#  (524100, '72807C', 'SET/3 VANILLA SCENTED CANDLE IN BOX', 6, Decimal('4.25')),
#  (524100, '22071', 'SMALL WHITE RETROSPOT MUG IN BOX ', 1, Decimal('3.75')),
#  (524100, '20754', 'RETROSPOT RED WASHING UP GLOVES', 1, Decimal('2.10')),
#  (524100, '21896', 'POTTING SHED TWINE', 1, Decimal('2.10')),
#  (524100, '21561', 'DINOSAUR LUNCH BOX WITH CUTLERY', 2, Decimal('2.55')),
#  (524100, '21491', 'SET OF THREE VINTAGE GIFT WRAPS', 4, Decimal('1.95')),
#  (524100, '22900', ' SET 2 TEA TOWELS I LOVE LONDON ', 1, Decimal('2.95')),
#  (524100, '47504K', 'ENGLISH ROSE GARDEN SECATEURS', 5, Decimal('1.95')),
#  (524100, '21981', 'PACK OF 12 WOODLAND TISSUES ', 12, Decimal('0.29')),
#  (524100, '35400', 'WOODEN BOX ADVENT CALENDAR ', 1, Decimal('8.95')),
#  (524100, '22666', 'RECIPE BOX PANTRY YELLOW DESIGN', 1, Decimal('2.95')),
#  (524100, '21098', 'CHRISTMAS TOILET ROLL', 8, Decimal('1.25')),
#  (524100, '22426', 'ENAMEL WASH BOWL CREAM', 1, Decimal('3.75')),
#  (524100, '22425', 'ENAMEL COLANDER CREAM', 1, Decimal('4.95')),
#  (524100, '22429', 'ENAMEL MEASURING JUG CREAM', 1, Decimal('4.25')),
#  (524100, '79164', 'BLACK WINE GLASS', 6, Decimal('1.65')),
#  (524100, '21134', 'VICTORIAN METAL POSTCARD CHRISTMAS', 3, Decimal('1.65')),
#  (524100, '84865', 'NEW BAROQUE BLACK PHOTO ALBUM', 1, Decimal('8.50')),
#  (524100, '17003', 'BROCADE RING PURSE ', 4, Decimal('0.21')),
#  (524100, '21675', 'BUTTERFLIES STICKERS', 6, Decimal('0.85')),
#  (524100, '85185B', 'PINK HORSE SOCK PUPPET', 1, Decimal('2.95')),
#  (524100, '85185D', 'FROG SOCK PUPPET', 1, Decimal('2.95')),
#  (524100, '72131', 'COLUMBIAN CANDLE RECTANGLE', 3, Decimal('1.95')),
#  (524101, '21826', 'EIGHT PIECE DINOSAUR SET', 2, Decimal('1.25')),
#  (524101, '21825', 'PAINTED METAL TREE WITH HOLLY BELLS', 3, Decimal('1.45')),
#  (524102, '85036A', 'GARDENIA 1 WICK MORRIS BOXED CANDLE', 6, Decimal('4.25')),
#  (524102, '84820', 'DANISH ROSE TRINKET TRAYS', 2, Decimal('5.95')),
#  (524102, '22637', 'PIGGY BANK RETROSPOT ', 4, Decimal('2.55')),
#  (524102, '22509', 'SEWING BOX RETROSPOT DESIGN ', 2, Decimal('16.95')),
#  (524102, '21333', 'CLASSIC WHITE FRAME', 2, Decimal('2.95')),
#  (524102, '21618', '4 WILDFLOWER BOTANICAL CANDLES', 5, Decimal('3.75')),
#  (524102, '84415A', 'PINK FLOCK SUEDE CUSHION COVER ', 2, Decimal('3.75')),
#  (524102, '84415B', 'BLUE FLOCK CUSHION COVER ', 2, Decimal('3.75')),
#  (524102, '22554', 'PLASTERS IN TIN WOODLAND ANIMALS', 2, Decimal('1.65')),
#  (524102, '22557', 'PLASTERS IN TIN VINTAGE PAISLEY ', 4, Decimal('1.65')),
#  (524102, '82613C', 'METAL SIGN,CUPCAKE SINGLE HOOK', 8, Decimal('1.25')),
#  (524102, '85119', 'WATERING CAN SINGLE HOOK PISTACHIO', 2, Decimal('1.69')),
#  (524102, '84908A', 'PINK 5 PATCH FLOWER CUSHION COVER ', 1, Decimal('6.95')),
#  (524102, '84919', 'BLUE CUSHION COVER WITH FLOWER', 4, Decimal('6.95')),
#  (524102, '84918', 'CREAM CUSHION COVER WITH FLOWERS', 2, Decimal('6.95')),
#  (524102, '84910A', 'PINK PAISLEY CUSHION COVER ', 2, Decimal('5.95')),
#  (524102, '21279', 'VINTAGE KITCHEN PRINT FRUITS', 4, Decimal('2.55')),
#  (524102, '22507', 'MEMO BOARD RETROSPOT  DESIGN', 2, Decimal('4.95')),
#  (524102, '21623', 'VINTAGE UNION JACK MEMOBOARD', 2, Decimal('9.95')),
#  (524102, '21896', 'POTTING SHED TWINE', 3, Decimal('2.10')),
#  (524102, '84843', 'WHITE SOAP RACK WITH 2 BOTTLES', 2, Decimal('5.95')),
#  (524102, '84631', 'FRUIT TREE AND BIRDS WALL PLAQUE', 2, Decimal('7.95')),
#  (524102, '84637', 'KITCHEN FLOWER POTS WALL PLAQUE', 2, Decimal('5.95')),
#  (524102, '21431', 'GREEN GINGHAM FLOWER JEWELLERY BOX', 4, Decimal('1.65')),
#  (524102, '22395', 'PAPERWEIGHT VINTAGE PAISLEY', 8, Decimal('2.55')),
#  (524102, '22488', 'NATURAL SLATE RECTANGLE CHALKBOARD', 2, Decimal('1.65')),
#  (524102, '22457', 'NATURAL SLATE HEART CHALKBOARD ', 2, Decimal('2.95')),
#  (524102, '84620', 'BLUE GINGHAM ROSE CUSHION COVER', 2, Decimal('5.95')),
#  (524102, '21034', 'REX CASH+CARRY JUMBO SHOPPER', 1, Decimal('0.95')),
#  (524102, '22180', 'RETROSPOT LAMP', 4, Decimal('9.95')),
#  (524102, '84658', 'WHITE STITCHED CUSHION COVER', 2, Decimal('6.95')),
#  (524102, '84818', 'DANISH ROSE PHOTO FRAME', 2, Decimal('2.55')),
#  (524102, '82482', 'WOODEN PICTURE FRAME WHITE FINISH', 4, Decimal('2.55')),
#  (524102, '21429', 'RED GINGHAM ROSE JEWELLERY BOX', 4, Decimal('1.65')),
#  (524102, '82483', 'WOOD 2 DRAWER CABINET WHITE FINISH', 2, Decimal('5.95')),
#  (524102, '22170', 'PICTURE FRAME WOOD TRIPLE PORTRAIT', 1, Decimal('6.75')),
#  (524102, '84847', 'FLORAL BATHROOM SET', 2, Decimal('3.75')),
#  (524102, '21590', 'KINGS CHOICE CIGAR BOX MATCHES ', 4, Decimal('1.25')),
#  (524102, '21584', 'RETROSPOT SMALL TUBE MATCHES', 3, Decimal('1.65')),
#  (524102, '21538', 'DAIRY MAID  PUDDING BOWL', 2, Decimal('3.75')),
#  (524102, '21537', 'RED RETROSPOT PUDDING BOWL', 2, Decimal('4.25')),
#  (524102, '21875', 'KINGS CHOICE MUG', 6, Decimal('1.25')),
#  (524102, '21531', 'RED RETROSPOT SUGAR JAM BOWL', 3, Decimal('2.55')),
#  (524102, '21535', 'RED RETROSPOT SMALL MILK JUG', 3, Decimal('2.55')),
#  (524102, '84969', 'BOX OF 6 ASSORTED COLOUR TEASPOONS', 3, Decimal('4.25')),
#  (524102, '21528', 'DAIRY MAID TRADITIONAL TEAPOT ', 3, Decimal('6.95')),
#  (524102, '21539', 'RED RETROSPOT BUTTER DISH', 2, Decimal('4.95')),
#  (524102,
#   '82607A',
#   'GLASS BONBON JAR PARFUME AUX FLEURE',
#   12,
#   Decimal('1.25')),
#  (524102, '21773', 'DECORATIVE ROSE BATHROOM BOTTLE', 12, Decimal('1.25')),
#  (524102, '21527', 'RED RETROSPOT TRADITIONAL TEAPOT ', 1, Decimal('7.95')),
#  (524102, '21844', 'RED RETROSPOT MUG', 18, Decimal('2.95')),
#  (524102, '21527', 'RED RETROSPOT TRADITIONAL TEAPOT ', 2, Decimal('7.95')),
#  (524102, '21533', 'RETROSPOT LARGE MILK JUG', 2, Decimal('4.95')),
#  (524102, '21534', 'DAIRY MAID LARGE MILK JUG', 3, Decimal('4.95')),
#  (524102, '21212', 'PACK OF 72 RETROSPOT CAKE CASES', 12, Decimal('0.55')),
#  (524102, '21977', 'PACK OF 60 PINK PAISLEY CAKE CASES', 12, Decimal('0.55')),
#  (524102, '84992', '72 SWEETHEART FAIRY CAKE CASES', 12, Decimal('0.55')),
#  (524102, '84991', '60 TEATIME FAIRY CAKE CASES', 12, Decimal('0.55')),
#  (524102, '84520B', 'PACK 20 ENGLISH ROSE PAPER NAPKINS', 5, Decimal('0.85')),
#  (524102, '22851', 'SET 20 NAPKINS FAIRY CAKES DESIGN ', 3, Decimal('0.85')),
#  (524102, '21080', 'SET/20 RED RETROSPOT PAPER NAPKINS ', 5, Decimal('0.85')),
#  (524102, '22908', 'PACK OF 20 NAPKINS RED APPLES', 5, Decimal('0.85')),
#  (524102, '21845', 'DAIRY MAID STRIPE MUG', 12, Decimal('2.95')),
#  (524102, '37343', 'POLKADOT MUG PINK ', 6, Decimal('1.65')),
#  (524103, '21790', 'VINTAGE SNAP CARDS', 24, Decimal('0.85')),
#  (524103, '21260', 'FIRST AID TIN', 12, Decimal('3.25')),
#  (524104, '22946', 'WOODEN ADVENT CALENDAR CREAM', 2, Decimal('16.95')),
#  (524104, '22945', 'CHRISTMAS METAL TAGS ASSORTED ', 12, Decimal('0.85')),
#  (524105, '21135', 'VICTORIAN  METAL POSTCARD SPRING', 2, Decimal('1.69')),
#  (524105, '21134', 'VICTORIAN METAL POSTCARD CHRISTMAS', 2, Decimal('1.65')),
#  (524105, '22904', 'CALENDAR PAPER CUT DESIGN', 2, Decimal('2.95')),
#  (524105, '21016', 'LIGHT BIRD HOUSE TREE DECORATION', 1, Decimal('0.85')),
#  (524105, '22735', 'RIBBON REEL SOCKS AND MITTENS', 1, Decimal('1.65')),
#  (524105, '22738', 'RIBBON REEL SNOWY VILLAGE', 1, Decimal('1.65')),
#  (524105, '22736', 'RIBBON REEL MAKING SNOWMEN ', 1, Decimal('1.65')),
#  (524105, '22739', 'RIBBON REEL CHRISTMAS SOCK BAUBLE', 1, Decimal('1.65')),
#  (524105, '22952', '60 CAKE CASES VINTAGE CHRISTMAS', 1, Decimal('0.55')),
#  (524105, '72814', 'SET OF 3 CHRISTMAS BRIAR CANDLES', 1, Decimal('3.75')),
#  (524105, '22187', 'GREEN CHRISTMAS TREE CARD HOLDER', 1, Decimal('4.25')),
#  (524105, '22588', 'CARD HOLDER GINGHAM HEART', 1, Decimal('2.55')),
#  (524105, '22589', 'CARDHOLDER GINGHAM STAR', 1, Decimal('2.55')),
#  (524105, '22186', 'RED STAR CARD HOLDER', 2, Decimal('2.95')),
#  (524105, '84247E', 'PACK/12 XMAS FUN CARD', 1, Decimal('2.95')),
#  (524105, '22818', 'CARD CHRISTMAS VILLAGE', 12, Decimal('0.42')),
#  (524105, '22816', 'CARD MOTORBIKE SANTA', 12, Decimal('0.42')),
#  (524105, '22732', '3D VINTAGE CHRISTMAS STICKERS ', 1, Decimal('1.25')),
#  (524105, '72815', '3 WICK CHRISTMAS BRIAR CANDLE ', 2, Decimal('3.75')),
#  (524105, '22728', 'ALARM CLOCK BAKELIKE PINK', 1, Decimal('3.75')),
#  (524105, '22729', 'ALARM CLOCK BAKELIKE ORANGE', 1, Decimal('3.75')),
#  (524105, '22726', 'ALARM CLOCK BAKELIKE GREEN', 1, Decimal('3.75')),
#  (524105, '22049', 'WRAP CHRISTMAS SCREEN PRINT', 25, Decimal('0.42')),
#  (524105, '21491', 'SET OF THREE VINTAGE GIFT WRAPS', 1, Decimal('1.95')),
#  (524105, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 2, Decimal('0.85')),
#  (524105, '22813', 'PACK 3 BOXES BIRD PANNETONE ', 1, Decimal('1.95')),
#  (524105, '22731', '3D CHRISTMAS STAMPS STICKERS ', 2, Decimal('1.25')),
#  (524105, '21070', 'VINTAGE BILLBOARD MUG ', 2, Decimal('1.25')),
#  (524105, '22114', 'HOT WATER BOTTLE TEA AND SYMPATHY', 1, Decimal('3.95')),
#  (524105, '21481', 'FAWN BLUE HOT WATER BOTTLE', 1, Decimal('2.95')),
#  (524105, '84030E', 'ENGLISH ROSE HOT WATER BOTTLE', 1, Decimal('4.25')),
#  (524105, '22835', 'HOT WATER BOTTLE I AM SO POORLY', 1, Decimal('4.65')),
#  (524105, '22113', 'GREY HEART HOT WATER BOTTLE', 1, Decimal('3.75')),
#  (524105, '22946', 'WOODEN ADVENT CALENDAR CREAM', 1, Decimal('16.95')),
#  (524105, '22867', 'HAND WARMER BIRD DESIGN', 1, Decimal('2.10')),
#  (524105, '22865', 'HAND WARMER OWL DESIGN', 1, Decimal('2.10')),
#  (524105, '82567', 'AIRLINE LOUNGE,METAL SIGN', 2, Decimal('2.10')),
#  (524105, '85150', 'LADIES & GENTLEMEN METAL SIGN', 1, Decimal('2.55')),
#  (524105, '21172', 'PARTY METAL SIGN ', 1, Decimal('1.45')),
#  (524105, '21171', 'BATHROOM METAL SIGN ', 2, Decimal('1.45')),
#  (524105, '21179', 'NO JUNK MAIL METAL SIGN', 1, Decimal('1.25')),
#  (524105, '21166', 'COOK WITH WINE METAL SIGN ', 1, Decimal('1.95')),
#  (524105, '35838A', 'S/6 MULTICOLOUR ORNAMENETAL CANDLE', 1, Decimal('0.85')),
#  (524105, '22666', 'RECIPE BOX PANTRY YELLOW DESIGN', 1, Decimal('2.95')),
#  (524105, '22665', 'RECIPE BOX BLUE SKETCHBOOK DESIGN', 1, Decimal('2.95')),
#  (524105, '85164B', 'BLACK BAROQUE CUCKOO CLOCK', 2, Decimal('12.75')),
#  (524105, '82486', 'WOOD S/3 CABINET ANT WHITE FINISH', 1, Decimal('7.95')),
#  (524105, '85167B', 'BLACK GRAND BAROQUE PHOTO FRAME', 1, Decimal('4.25')),
#  (524105, '85099C', 'JUMBO  BAG BAROQUE BLACK WHITE', 1, Decimal('1.95')),
#  (524105, '22411', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 1, Decimal('1.95')),
#  (524105, '22386', 'JUMBO BAG PINK POLKADOT', 1, Decimal('1.95')),
#  (524105, '21034', 'REX CASH+CARRY JUMBO SHOPPER', 1, Decimal('0.95')),
#  (524105, '22086', "PAPER CHAIN KIT 50'S CHRISTMAS ", 1, Decimal('2.95')),
#  (524105, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 3, Decimal('2.95')),
#  (524105, '21591', 'COSY HOUR CIGAR BOX MATCHES ', 3, Decimal('1.25')),
#  (524105, '22467', 'GUMBALL COAT RACK', 1, Decimal('2.55')),
#  (524105, '21071', 'VINTAGE BILLBOARD DRINK ME MUG', 2, Decimal('1.25')),
#  (524106, '47566', 'PARTY BUNTING', 150, Decimal('3.75')),
#  (524107, '21793', 'CLASSIC FRENCH STYLE BASKET BROWN', 2, Decimal('6.75')),
#  (524107, '84682', 'CLASSICAL ROSE DISH', 24, Decimal('1.25')),
#  (524107, '20892', 'SET/3 TALL GLASS CANDLE HOLDER PINK', 2, Decimal('12.75')),
#  (524107, '21121', 'SET/10 RED POLKADOT PARTY CANDLES', 24, Decimal('1.25')),
#  (524107, '35400', 'WOODEN BOX ADVENT CALENDAR ', 2, Decimal('8.95')),
#  (524107, '21448', '12 DAISY PEGS IN WOOD BOX', 12, Decimal('1.65')),
#  (524107, '84823', 'DANISH ROSE FOLDING CHAIR', 1, Decimal('39.95')),
#  (524107, '22713', 'CARD I LOVE LONDON ', 12, Decimal('0.42')),
#  (524107, '20871', 'OPULENT VELVET SET/3 CANDLES', 24, Decimal('1.25')),
#  (524107, '20685', 'DOORMAT RED RETROSPOT', 10, Decimal('6.75')),
#  (524107, '22804', 'CANDLEHOLDER PINK HANGING HEART', 6, Decimal('2.95')),
#  (524107, '21792', 'CLASSIC FRENCH STYLE BASKET GREEN ', 2, Decimal('6.75')),
#  (524107, '84536A', 'ENGLISH ROSE NOTEBOOK A7 SIZE', 16, Decimal('0.42')),
#  (524108, '21098', 'CHRISTMAS TOILET ROLL', 24, Decimal('1.25')),
#  (524108, '22580', 'ADVENT CALENDAR GINGHAM SACK', 3, Decimal('5.95')),
#  (524108, '72741', 'GRAND CHOCOLATECANDLE', 72, Decimal('1.25')),
#  (524108, '22596', 'CHRISTMAS STAR WISH LIST CHALKBOARD', 12, Decimal('0.85')),
#  (524108, '22694', 'WICKER STAR ', 12, Decimal('2.10')),
#  (524108, '22649', 'STRAWBERRY FAIRY CAKE TEAPOT', 8, Decimal('4.95')),
#  (524108, '22061', 'LARGE CAKE STAND  HANGING STRAWBERY', 12, Decimal('8.50')),
#  (524108, '22666', 'RECIPE BOX PANTRY YELLOW DESIGN', 6, Decimal('2.95')),
#  (524108, '84380', 'SET OF 3 BUTTERFLY COOKIE CUTTERS', 12, Decimal('1.25')),
#  (524108, '21217', 'RED SPOTTY ROUND CAKE TINS', 12, Decimal('8.95')),
#  (524108, '20914', 'SET/5 RED SPOTTY LID GLASS BOWLS', 32, Decimal('2.55')),
#  (524108, '21154', 'RED SPOTTY OVEN GLOVE ', 10, Decimal('1.25')),
#  (524108, '21155', 'RED SPOTTY PEG BAG', 6, Decimal('2.10')),
#  (524108, '20972', 'PINK CREAM FELT CRAFT TRINKET BOX ', 24, Decimal('1.25')),
#  (524108, '22147', 'FELTCRAFT BUTTERFLY HEARTS', 12, Decimal('1.45')),
#  (524108, '22274', 'FELTCRAFT DOLL EMILY', 12, Decimal('2.95')),
#  (524108, '22749', 'FELTCRAFT PRINCESS CHARLOTTE DOLL', 8, Decimal('3.75')),
#  (524108, '22568', 'FELTCRAFT CUSHION OWL', 8, Decimal('3.75')),
#  (524108, '22569', 'FELTCRAFT CUSHION BUTTERFLY', 8, Decimal('3.75')),
#  (524108, '22175', 'PINK OWL SOFT TOY', 6, Decimal('2.95')),
#  (524108, '22176', 'BLUE OWL SOFT TOY', 6, Decimal('2.95')),
#  (524108, '22620', '4 TRADITIONAL SPINNING TOPS', 12, Decimal('1.25')),
#  (524108, '21890', 'S/6 WOODEN SKITTLES IN COTTON BAG', 12, Decimal('2.95')),
#  (524108, '20713', 'JUMBO BAG OWLS', 100, Decimal('1.65')),
#  (524108, '85099B', 'JUMBO BAG RED RETROSPOT', 100, Decimal('1.65')),
#  (524108, '20725', 'LUNCH BAG RED SPOTTY', 100, Decimal('1.45')),
#  (524109, '22505', 'MEMO BOARD COTTAGE DESIGN', 4, Decimal('4.95')),
#  (524109, '22472', 'TV DINNER TRAY DOLLY GIRL', 6, Decimal('4.95')),
#  (524109, '22445', 'PENCIL CASE LIFE IS BEAUTIFUL', 6, Decimal('2.95')),
#  (524109, '22554', 'PLASTERS IN TIN WOODLAND ANIMALS', 12, Decimal('1.65')),
#  (524109, '22556', 'PLASTERS IN TIN CIRCUS PARADE ', 12, Decimal('1.65')),
#  (524109, '22646', 'CERAMIC STRAWBERRY CAKE MONEY BANK', 12, Decimal('1.45')),
#  (524109, '22644', 'CERAMIC CHERRY CAKE MONEY BANK', 12, Decimal('1.45')),
#  (524109, '22649', 'STRAWBERRY FAIRY CAKE TEAPOT', 8, Decimal('4.95')),
#  (524109, '22759', 'SET OF 3 NOTEBOOKS IN PARCEL', 12, Decimal('1.65')),
#  (524109, '22752', 'SET 7 BABUSHKA NESTING BOXES', 6, Decimal('8.50')),
#  (524109, '22743', 'MAKE YOUR OWN FLOWERPOWER CARD KIT', 6, Decimal('2.95')),
#  (524109, 'POST', 'POSTAGE', 8, Decimal('18.00')),
#  (524109, '84988', 'SET OF 72 PINK HEART PAPER DOILIES', 12, Decimal('1.45')),
#  (524109, '21210', 'SET OF 72 RETRO SPOT PAPER  DOILIES', 12, Decimal('1.45')),
#  (524109, '20719', 'WOODLAND CHARLOTTE BAG', 20, Decimal('0.85')),
#  (524109, '20914', 'SET/5 RED RETROSPOT LID GLASS BOWLS', 12, Decimal('2.95')),
#  (524109, '21578', 'WOODLAND DESIGN  COTTON TOTE BAG', 6, Decimal('2.25')),
#  (524109, '21577', 'SAVE THE PLANET COTTON TOTE BAG', 6, Decimal('2.25')),
#  (524109, '21700', 'BIG DOUGHNUT FRIDGE MAGNETS', 12, Decimal('0.85')),
#  (524109, '21080', 'SET/20 RED SPOTTY PAPER NAPKINS ', 12, Decimal('0.85')),
#  (524109, '22423', 'REGENCY CAKESTAND 3 TIER', 16, Decimal('10.95')),
#  (524109, '22457', 'NATURAL SLATE HEART CHALKBOARD ', 12, Decimal('2.95')),
#  (524110, '22951', '72 CAKE CASES DOLLY GIRL DESIGN', 24, Decimal('0.55')),
#  (524110, '22949', '36 DOILIES DOLLY GIRL', 12, Decimal('1.45')),
#  (524110, '22908', 'PACK OF 20 NAPKINS RED APPLES', 12, Decimal('0.85')),
#  (524110, '22907', 'PACK OF 20 NAPKINS PANTRY DESIGN', 12, Decimal('0.85')),
#  (524110, '22894', 'TABLECLOTH RED APPLES DESIGN ', 2, Decimal('8.50')),
#  (524110, '22897', 'OVEN MITT APPLE DESIGN', 10, Decimal('1.45')),
#  (524110, '22820', 'GIFT BAG BIRTHDAY', 12, Decimal('0.65')),
#  (524110, '22813', 'PACK 3 BOXES BIRD PANNETONE ', 12, Decimal('1.95')),
#  (524110, '22806', 'SET OF 6 T-LIGHTS WEDDING CAKE ', 6, Decimal('2.95')),
#  (524111, '22816', 'CARD MOTORBIKE SANTA', 24, Decimal('0.42')),
#  (524111, '22809', 'SET OF 6 T-LIGHTS SANTA', 12, Decimal('2.95')),
#  (524111, '22812', 'PACK 3 BOXES CHRISTMAS PANNETONE', 36, Decimal('1.95')),
#  (524111, '22945', 'CHRISTMAS METAL TAGS ASSORTED ', 24, Decimal('0.85')),
#  (524111, '22734', 'SET OF 6 RIBBONS VINTAGE CHRISTMAS', 36, Decimal('2.55')),
#  (524111, '22739', 'RIBBON REEL, XMAS SOCK/BAUBLE', 30, Decimal('1.65')),
#  (524111, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 48, Decimal('0.55')),
#  (524111, '22950', '36 DOILIES VINTAGE CHRISTMAS', 36, Decimal('1.45')),
#  (524111, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 36, Decimal('0.85')),
#  (524111, '22733', '3D STICKERS TRADITIONAL CHRISTMAS ', 40, Decimal('1.25')),
#  (524111, '22731', '3D STICKERS CHRISTMAS STAMPS', 40, Decimal('1.25')),
#  (524111, '22467', 'GUMBALL COAT RACK', 18, Decimal('2.55')),
#  (524112, '84989A', '75 GREEN FAIRY CAKE CASES', 24, Decimal('0.55')),
#  (524112, '21975', 'PACK OF 60 DINOSAUR CAKE CASES', 24, Decimal('0.55')),
#  (524112, '22951', '72 CAKE CASES DOLLY GIRL DESIGN', 24, Decimal('0.55')),
#  (524112, '21977', 'PACK OF 60 PINK PAISLEY CAKE CASES', 24, Decimal('0.55')),
#  (524112, '22196', 'SMALL HEART MEASURING SPOONS', 12, Decimal('0.85')),
#  (524112, '22195', 'LARGE HEART MEASURING SPOONS', 12, Decimal('1.65')),
#  (524112, '84992', '72 SWEETHEART FAIRY CAKE CASES', 24, Decimal('0.55')),
#  (524112, '22435', 'SET OF 9 HEART SHAPED BALLOONS', 12, Decimal('1.25')),
#  (524112, '22089', 'PAPER BUNTING VINTAGE PAISLEY', 6, Decimal('2.95')),
#  (524112, '22939', 'APRON APPLE DELIGHT', 2, Decimal('4.95')),
#  (524112, '22898', 'CHILDRENS APRON APPLE DESIGN', 8, Decimal('1.95')),
#  (524112, '22851', 'SET 20 NAPKINS FAIRY CAKES DESIGN ', 12, Decimal('0.85')),
#  (524112, '21122', 'SET/10 PINK SPOTTY PARTY CANDLES', 24, Decimal('1.25')),
#  (524112, '22083', 'PAPER CHAIN KIT RETRO SPOT', 6, Decimal('2.95')),
#  (524112, '21215', 'IVORY PAPER CUP CAKE CASES ', 24, Decimal('0.55')),
#  (524112, '22938', 'CUPCAKE LACE PAPER SET 6', 12, Decimal('1.95')),
#  (524112, '22222', 'CAKE PLATE LOVEBIRD WHITE', 3, Decimal('4.95')),
#  (524112, '22220', 'CAKE STAND LOVEBIRD 2 TIER WHITE', 2, Decimal('9.95')),
#  (524112, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 6, Decimal('2.95')),
#  (524112, '22734', 'SET OF 6 RIBBONS VINTAGE CHRISTMAS', 6, Decimal('2.55')),
#  (524112, '22818', 'CARD CHRISTMAS VILLAGE', 12, Decimal('0.42')),
#  (524112, '22959', 'WRAP CHRISTMAS VILLAGE', 25, Decimal('0.42')),
#  (524112, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 24, Decimal('0.55')),
#  (524112, '22733', '3D STICKERS TRADITIONAL CHRISTMAS ', 20, Decimal('1.25')),
#  (524112, '22732', '3D STICKERS VINTAGE CHRISTMAS', 20, Decimal('1.25')),
#  (524112, '22731', '3D STICKERS CHRISTMAS STAMPS', 20, Decimal('1.25')),
#  (524112, '22423', 'REGENCY CAKESTAND 3 TIER', 4, Decimal('12.75')),
#  (524112, '22567', '20 DOLLY PEGS RETROSPOT', 12, Decimal('1.25')),
#  (524112, '47567B', 'TEA TIME KITCHEN APRON', 3, Decimal('5.95')),
#  (524112, '21042', 'RED SPOTTY APRON ', 3, Decimal('5.95')),
#  (524112, '47591D', 'PINK FAIRY CAKE CHILDRENS APRON', 8, Decimal('1.95')),
# ...
#  (524116, '22145', 'CHRISTMAS CRAFT HEART STOCKING ', 3, Decimal('2.10')),
#  (524116, '22143', 'CHRISTMAS CRAFT HEART DECORATIONS', 2, Decimal('2.10')),
#  (524116, '22469', 'HEART OF WICKER SMALL', 8, Decimal('1.65')),
#  (524116, '84459B', 'YELLOW METAL CHICKEN HEART ', 2, Decimal('1.49')),
#  (524116, '84459A', 'PINK METAL CHICKEN HEART ', 2, Decimal('1.49')),
#  (524116, '22457', 'NATURAL SLATE HEART CHALKBOARD ', 4, Decimal('2.95')),
#  (524116, '22855', 'FINE WICKER HEART ', 6, Decimal('1.25')),
#  (524116, '22507', 'MEMO BOARD RETROSPOT  DESIGN', 1, Decimal('4.95')),
#  (524116, '22169', 'FAMILY ALBUM WHITE PICTURE FRAME', 4, Decimal('8.50')),
#  (524116, '21350', 'GINGHAM HEART WREATH', 2, Decimal('2.95')),
#  (524118, '22726', 'ALARM CLOCK BAKELIKE GREEN', 4, Decimal('3.75')),
#  (524118, '22727', 'ALARM CLOCK BAKELIKE RED ', 4, Decimal('3.75')),
#  (524118, '22699', 'ROSES REGENCY TEACUP AND SAUCER ', 6, Decimal('2.95')),
#  (524118, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 24, Decimal('2.95')),
#  (524118, '22423', 'REGENCY CAKESTAND 3 TIER', 6, Decimal('12.75')),
#  (524118, '22895', 'SET OF 2 TEA TOWELS APPLE AND PEARS', 48, Decimal('2.95')),
#  (524118, '22303', 'COFFEE MUG APPLES DESIGN', 12, Decimal('2.55')),
#  (524118, '22300', 'COFFEE MUG DOG + BALL DESIGN', 12, Decimal('2.55')),
#  (524118, '22301', 'COFFEE MUG CAT + BIRD DESIGN', 12, Decimal('2.55')),
#  (524118, '22220', 'CAKE STAND LOVEBIRD 2 TIER WHITE', 4, Decimal('9.95')),
#  (524118, '22219', 'LOVEBIRD HANGING DECORATION WHITE ', 24, Decimal('0.85')),
#  (524118, '21524', 'DOORMAT SPOTTY HOME SWEET HOME', 10, Decimal('6.75')),
#  (524118, '22904', 'CALENDAR PAPER CUT DESIGN', 12, Decimal('2.95')),
#  (524118, '22959', 'WRAP CHRISTMAS VILLAGE', 25, Decimal('0.42')),
#  (524118, '22813', 'PACK 3 BOXES BIRD PANNETONE ', 24, Decimal('1.95')),
#  (524118, '21181', 'PLEASE ONE PERSON METAL SIGN', 12, Decimal('2.10')),
#  (524118, '22117', 'METAL SIGN HER DINNER IS SERVED ', 6, Decimal('2.95')),
#  (524118, '82551', 'LAUNDRY 15C METAL SIGN', 12, Decimal('1.45')),
#  (524118, '22636', 'CHILDS BREAKFAST SET CIRCUS PARADE', 4, Decimal('8.50')),
#  (524118, '22630', 'DOLLY GIRL LUNCH BOX', 12, Decimal('1.95')),
#  (524118, '22634', 'CHILDS BREAKFAST SET SPACEBOY ', 2, Decimal('9.95')),
#  (524118, '22551', 'PLASTERS IN TIN SPACEBOY', 12, Decimal('1.65')),
#  (524118, '22629', 'SPACEBOY LUNCH BOX ', 12, Decimal('1.95')),
#  (524118, '21871', 'SAVE THE PLANET MUG', 12, Decimal('1.25')),
#  (524118, '21873', "IF YOU CAN'T STAND THE HEAT MUG", 12, Decimal('1.25')),
#  (524118, '21877', 'HOME SWEET HOME MUG', 12, Decimal('1.25')),
#  (524118, '21868', 'POTTING SHED TEA MUG', 12, Decimal('1.25')),
#  (524118, '22730', 'ALARM CLOCK BAKELIKE IVORY', 4, Decimal('3.75')),
#  (524118, '22306', 'SILVER MUG BONE CHINA TREE OF LIFE', 12, Decimal('1.95')),
#  (524118, '21491', 'SET OF THREE VINTAGE GIFT WRAPS', 24, Decimal('1.95')),
#  (524118,
#   '85199L',
#   'LARGE HANGING IVORY & RED WOOD BIRD',
#   72,
#   Decimal('0.65')),
#  (524118, '84945', 'MULTI COLOUR SILVER T-LIGHT HOLDER', 60, Decimal('0.85')),
#  (524118, '22687', 'DOORMAT CHRISTMAS VILLAGE', 6, Decimal('7.95')),
#  (524118, '22950', '36 DOILIES VINTAGE CHRISTMAS', 36, Decimal('1.45')),
#  (524118, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 36, Decimal('0.85')),
#  (524118, '22738', 'RIBBON REEL SNOWY VILLAGE', 30, Decimal('1.65')),
#  (524118, '22733', '3D STICKERS TRADITIONAL CHRISTMAS ', 40, Decimal('1.25')),
#  (524118, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 72, Decimal('0.55')),
#  (524118, '22734', 'SET OF 6 RIBBONS VINTAGE CHRISTMAS', 48, Decimal('2.55')),
#  (524119, '71053', 'WHITE METAL LANTERN', 48, Decimal('3.39')),
#  (524121, '22138', 'BAKING SET 9 PIECE RETROSPOT ', 3, Decimal('4.95')),
#  (524121, '22623', 'BOX OF VINTAGE JIGSAW BLOCKS ', 6, Decimal('4.95')),
#  (524121, '20727', 'LUNCH BAG  BLACK SKULL.', 10, Decimal('1.65')),
#  (524121, '22759', 'SET OF 3 NOTEBOOKS IN PARCEL', 12, Decimal('1.65')),
#  (524121, '22145', 'CHRISTMAS CRAFT HEART STOCKING ', 6, Decimal('2.10')),
#  (524121, '47566B', 'TEA TIME PARTY BUNTING', 10, Decimal('4.65')),
#  (524121, '47566', 'PARTY BUNTING', 10, Decimal('4.65')),
#  (524121, '22502', 'PICNIC BASKET WICKER SMALL', 8, Decimal('5.95')),
#  (524121, '84988', 'SET OF 72 PINK HEART PAPER DOILIES', 12, Decimal('1.45')),
#  (524121, '21878', 'PACK OF 6 SANDCASTLE FLAGS ASSORTED', 12, Decimal('0.85')),
#  (524121, '21791', 'VINTAGE HEADS AND TAILS CARD GAME ', 12, Decimal('1.25')),
#  (524121, '22851', 'SET 20 NAPKINS FAIRY CAKES DESIGN ', 12, Decimal('0.85')),
#  (524121, '10002', 'INFLATABLE POLITICAL GLOBE ', 12, Decimal('0.85')),
#  (524120, '21166', 'COOK WITH WINE METAL SIGN ', 6, Decimal('1.69')),
#  (524120, '21169', "YOU'RE CONFUSING ME METAL SIGN ", 6, Decimal('1.45')),
#  (524120, '21165', 'BEWARE OF THE CAT METAL SIGN ', 12, Decimal('1.45')),
#  (524121, '22617', 'BAKING SET SPACEBOY DESIGN', 6, Decimal('4.95')),
#  (524121, '22554', 'PLASTERS IN TIN WOODLAND ANIMALS', 12, Decimal('1.65')),
#  (524121, '22553', 'PLASTERS IN TIN SKULLS', 12, Decimal('1.65')),
#  (524121, '22139', 'RETRO SPOT TEA SET CERAMIC 11 PC ', 6, Decimal('4.95')),
#  (524125, '22624', 'IVORY KITCHEN SCALES', 2, Decimal('8.50')),
#  (524125, '21731', 'RED TOADSTOOL LED NIGHT LIGHT', 12, Decimal('1.65')),
#  (524125, '20972', 'PINK CREAM FELT CRAFT TRINKET BOX ', 12, Decimal('1.25')),
#  (524125, '22940', 'FELTCRAFT CHRISTMAS FAIRY', 8, Decimal('4.25')),
#  (524125, '22751', 'FELTCRAFT PRINCESS OLIVIA DOLL', 8, Decimal('3.75')),
#  (524125, '10002', 'INFLATABLE POLITICAL GLOBE ', 12, Decimal('0.85')),
#  (524125, '84077', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 96, Decimal('0.29')),
#  (524125, '22613', 'PACK OF 20 SPACEBOY NAPKINS', 12, Decimal('0.85')),
#  (524125, '22745', "POPPY'S PLAYHOUSE BEDROOM ", 6, Decimal('2.10')),
#  (524125, '22748', "POPPY'S PLAYHOUSE KITCHEN", 6, Decimal('2.10')),
#  (524125, '22752', 'SET 7 BABUSHKA NESTING BOXES', 4, Decimal('8.50')),
#  (524125, '22754', 'SMALL RED BABUSHKA NOTEBOOK ', 12, Decimal('0.85')),
#  (524125, '22753', 'SMALL YELLOW BABUSHKA NOTEBOOK ', 12, Decimal('0.85')),
#  (524125, '22755', 'SMALL PURPLE BABUSHKA NOTEBOOK ', 12, Decimal('0.85')),
#  (524125, '22711', 'WRAP CIRCUS PARADE', 25, Decimal('0.42')),
#  (524125, '22706', 'WRAP COWBOYS  ', 25, Decimal('0.42')),
#  (524125, '22046', 'TEA PARTY  WRAPPING PAPER ', 25, Decimal('0.42')),
#  (524125, '22431', 'WATERING CAN BLUE ELEPHANT', 6, Decimal('1.95')),
#  (524125, '22419', 'LIPSTICK PEN RED', 12, Decimal('0.42')),
#  (524125, '20713', 'JUMBO BAG OWLS', 10, Decimal('1.95')),
#  (524125, '20711', 'JUMBO BAG TOYS ', 10, Decimal('1.95')),
#  (524125, '22663', 'JUMBO BAG DOLLY GIRL DESIGN', 10, Decimal('1.95')),
#  (524125, '21931', 'JUMBO STORAGE BAG SUKI', 10, Decimal('1.95')),
#  (524125, '22355', 'CHARLOTTE BAG SUKI DESIGN', 10, Decimal('0.85')),
#  (524125, '20723', 'STRAWBERRY CHARLOTTE BAG', 10, Decimal('0.85')),
#  (524125, '20724', 'RED SPOTTY CHARLOTTE BAG', 10, Decimal('0.85')),
#  (524125, '20725', 'LUNCH BAG RED SPOTTY', 20, Decimal('1.65')),
#  (524125, '22662', 'LUNCH BAG DOLLY GIRL DESIGN', 20, Decimal('1.65')),
#  (524125, '22382', 'LUNCH BAG SPACEBOY DESIGN ', 20, Decimal('1.65')),
#  (524125, '22383', 'LUNCH BAG SUKI  DESIGN ', 20, Decimal('1.65')),
#  (524125, '20726', 'LUNCH BAG WOODLAND', 20, Decimal('1.65')),
#  (524125, '22466', 'FAIRY TALE COTTAGE NIGHTLIGHT', 12, Decimal('1.95')),
#  (524125, '22467', 'GUMBALL COAT RACK', 6, Decimal('2.55')),
#  (524125, '22207', 'FRYING PAN UNION FLAG', 4, Decimal('4.25')),
#  (524125, '21975', 'PACK OF 60 DINOSAUR CAKE CASES', 24, Decimal('0.55')),
#  (524125, '20682', 'RED SPOTTY CHILDS UMBRELLA', 6, Decimal('3.25')),
#  (524125, '17003', 'BROCADE RING PURSE ', 50, Decimal('0.21')),
#  (524125, '85014A', 'BLACK/BLUE DOTS RUFFLED UMBRELLA', 6, Decimal('5.95')),
#  (524125, '85014B', 'RED/WHITE DOTS RUFFLED UMBRELLA', 6, Decimal('5.95')),
#  (524125, '15056BL', 'EDWARDIAN PARASOL BLACK', 6, Decimal('5.95')),
#  (524125, '15056N', 'EDWARDIAN PARASOL NATURAL', 6, Decimal('5.95')),
#  (524125, '21929', 'JUMBO BAG PINK VINTAGE PAISLEY', 10, Decimal('1.95')),
#  (524125, '21447', '12 IVORY ROSE PEG PLACE SETTINGS', 6, Decimal('1.25')),
#  (524125, '22411', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 10, Decimal('1.95')),
#  (524125, '21201', 'TROPICAL  HONEYCOMB PAPER GARLAND ', 12, Decimal('2.55')),
#  (524125, '22691', 'DOORMAT WELCOME SUNRISE', 2, Decimal('7.95')),
#  (524125, '22959', 'WRAP CHRISTMAS VILLAGE', 25, Decimal('0.42')),
#  (524125, '22738', 'RIBBON REEL SNOWY VILLAGE', 10, Decimal('1.65')),
#  (524125, '22733', '3D STICKERS TRADITIONAL CHRISTMAS ', 20, Decimal('1.25')),
#  (524125, '22952', '72 CAKE CASES VINTAGE CHRISTMAS', 24, Decimal('0.55')),
#  (524125, '22736', 'RIBBON REEL MAKING SNOWMEN ', 10, Decimal('1.65')),
#  (524125, '22910', 'PAPER CHAIN KIT VINTAGE CHRISTMAS', 18, Decimal('2.95')),
#  (524125, '22909', 'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 24, Decimal('0.85')),
#  (524125, '21137', 'BLACK RECORD COVER FRAME', 4, Decimal('3.75')),
#  (524125, '84212', 'ASSORTED FLOWER COLOUR "LEIS"', 24, Decimal('0.65')),
#  (524125, '79321', 'CHILLI LIGHTS', 16, Decimal('4.95')),
#  (524125, '21488', 'RED WHITE SCARF  HOT WATER BOTTLE', 8, Decimal('3.95')),
#  (524125, '21481', 'FAWN BLUE HOT WATER BOTTLE', 6, Decimal('2.95')),
#  (524125, '22866', 'HAND WARMER SCOTTY DOG DESIGN', 12, Decimal('2.10')),
#  (524125, '22834', 'HAND WARMER BABUSHKA DESIGN', 12, Decimal('2.10')),
#  (524125, '22865', 'HAND WARMER OWL DESIGN', 12, Decimal('2.10')),
#  (524125, '84347', 'ROTATING SILVER ANGELS T-LIGHT HLDR', 12, Decimal('2.55')),
#  (524125, '22907', 'PACK OF 20 NAPKINS PANTRY DESIGN', 12, Decimal('0.85')),
#  (524125, '22203', 'MILK PAN RED RETROSPOT', 4, Decimal('3.75')),
#  (524125, '22083', 'PAPER CHAIN KIT RETRO SPOT', 12, Decimal('2.95')),
#  (524125, '22090', 'PAPER BUNTING RETRO SPOTS', 6, Decimal('2.95')),
#  (524125, '84692', 'BOX OF 24 COCKTAIL PARASOLS', 50, Decimal('0.42')),
#  (524125, '22107', 'PIZZA PLATE IN BOX', 8, Decimal('3.75')),
#  (524125, '22109', 'FULL ENGLISH BREAKFAST PLATE', 12, Decimal('3.75')),
#  (524125, '22652', 'TRAVEL SEWING KIT', 6, Decimal('1.65')),
#  (524125, '21213', 'PACK OF 72 SKULL CAKE CASES', 24, Decimal('0.55')),
#  (524125, '22417', 'PACK OF 60 SPACEBOY CAKE CASES', 24, Decimal('0.55')),
#  (524125, '22951', '72 CAKE CASES DOLLY GIRL DESIGN', 24, Decimal('0.55')),
#  (524125, '21977', 'PACK OF 60 PINK PAISLEY CAKE CASES', 24, Decimal('0.55')),
#  (524125, '84991', '60 TEATIME FAIRY CAKE CASES', 48, Decimal('0.55')),
#  (524125, '22851', 'SET 20 NAPKINS FAIRY CAKES DESIGN ', 12, Decimal('0.85')),
#  (524125, '22174', 'PHOTO CUBE', 12, Decimal('1.65')),
#  (524125, '22088', 'PAPER BUNTING COLOURED LACE', 12, Decimal('2.95')),
#  (524125, '22136', 'LOVE HEART SOCK HANGER', 24, Decimal('1.65')),
#  (524125, '22195', 'LARGE HEART MEASURING SPOONS', 24, Decimal('1.65')),
#  (524125, '84380', 'SET OF 3 BUTTERFLY COOKIE CUTTERS', 12, Decimal('1.25')),
#  (524125, '84378', 'SET OF 3 HEART COOKIE CUTTERS', 12, Decimal('1.25')),
#  (524125, '22900', ' SET 2 TEA TOWELS I LOVE LONDON ', 3, Decimal('2.95')),
#  (524125, '22197', 'SMALL POPCORN HOLDER', 12, Decimal('0.85')),
#  (524125, '20914', 'SET/5 RED SPOTTY LID GLASS BOWLS', 6, Decimal('2.95')),
#  (524125, '21212', 'PACK OF 72 RETRO SPOT CAKE CASES', 24, Decimal('0.55')),
#  (524125, '21527', 'RED RETROSPOT TRADITIONAL TEAPOT ', 2, Decimal('7.95')),
#  (524125, '21786', 'RAIN HAT WITH RED SPOTS', 48, Decimal('0.42')),
#  (524125, '22199', 'FRYING PAN RED POLKADOT ', 4, Decimal('4.25')),
#  (524125, '22321', 'BIRD DECORATION RED SPOT', 12, Decimal('0.85')),
#  (524125, '22421', 'LIPSTICK PEN FUSCHIA', 12, Decimal('0.42')),
#  (524125, '22440', 'BALLOON WATER BOMB PACK OF 35', 20, Decimal('0.42')),
#  (524125, '22534', 'MAGIC DRAWING SLATE SPACEBOY ', 24, Decimal('0.42')),
#  (524125, '22530', 'MAGIC DRAWING SLATE DOLLY GIRL ', 24, Decimal('0.42')),
#  (524125, '22492', 'MINI PAINT SET VINTAGE ', 72, Decimal('0.65')),
#  (524125, '22623', 'BOX OF VINTAGE JIGSAW BLOCKS ', 6, Decimal('4.95')),
#  (524125, '22555', 'PLASTERS IN TIN STRONGMAN', 12, Decimal('1.65')),
#  (524125, '22551', 'PLASTERS IN TIN SPACEBOY', 12, Decimal('1.65')),
#  (524125, '22554', 'PLASTERS IN TIN WOODLAND ANIMALS', 12, Decimal('1.65')),
#  (524125, '21982', 'PACK OF 12 SUKI TISSUES ', 24, Decimal('0.29')),
#  (524125, '22616', 'PACK OF 12 LONDON TISSUES ', 24, Decimal('0.29')),
#  (524125, '22615', 'PACK OF 12 CIRCUS PARADE TISSUES ', 24, Decimal('0.29')),
#  (524125, '22614', 'PACK OF 12 SPACEBOY TISSUES', 24, Decimal('0.29')),
#  (524125, '22630', 'DOLLY GIRL LUNCH BOX', 12, Decimal('1.95')),
#  (524125, '22631', 'CIRCUS PARADE LUNCH BOX ', 12, Decimal('1.95')),
#  (524125, '22659', 'LUNCH BOX I LOVE LONDON', 12, Decimal('1.95')),
#  (524125, '22629', 'SPACEBOY LUNCH BOX ', 12, Decimal('1.95')),
#  (524125, '20712', 'JUMBO BAG WOODLAND ANIMALS', 10, Decimal('1.95')),
#  (524125, '85099F', 'JUMBO BAG STRAWBERRY', 10, Decimal('1.95')),
#  (524125, '85099B', 'JUMBO BAG RED RETROSPOT', 20, Decimal('1.95')),
#  (524128, '21877', 'HOME SWEET HOME MUG', 12, Decimal('1.25')),
#  (524128, '21876', 'POTTERING MUG', 12, Decimal('1.25')),
#  (524128, '21875', 'KINGS CHOICE MUG', 12, Decimal('1.25')),
#  (524128, '22561', 'WOODEN SCHOOL COLOURING SET', 12, Decimal('1.65')),
#  (524128, '82605', 'OLD DOC RUSSEL METAL SIGN', 6, Decimal('2.10')),
#  (524128, '21175', 'GIN + TONIC DIET METAL SIGN', 12, Decimal('2.10')),
#  (524128, '85152', 'HAND OVER THE CHOCOLATE   SIGN ', 12, Decimal('2.10')),
#  (524128, '22115', 'METAL SIGN EMPIRE TEA', 6, Decimal('2.95')),
#  (524128, '82600', 'NO SINGING METAL SIGN', 12, Decimal('2.10')),
#  (524128, '21908', 'CHOCOLATE THIS WAY METAL SIGN', 12, Decimal('2.10')),
#  (524128, '21181', 'PLEASE ONE PERSON METAL SIGN', 24, Decimal('2.10')),
#  (524128, '21174', 'POTTERING IN THE SHED METAL SIGN', 12, Decimal('1.95')),
#  (524128, '21179', 'NO JUNK MAIL METAL SIGN', 12, Decimal('1.25')),
#  (524128, '21164', 'HOME SWEET HOME METAL SIGN ', 6, Decimal('2.95')),
#  (524128, '21260', 'FIRST AID TIN', 6, Decimal('3.25')),
#  (524128, '85014B', 'RED/WHITE DOTS RUFFLED UMBRELLA', 6, Decimal('5.95')),
#  (524134, '21491', 'SET OF THREE VINTAGE GIFT WRAPS', 12, Decimal('1.95')),
#  (524134, '22959', 'WRAP CHRISTMAS VILLAGE', 25, Decimal('0.42')),
#  (524134, '22732', '3D STICKERS VINTAGE CHRISTMAS', 20, Decimal('1.25')),
#  (524134, '22731', '3D STICKERS CHRISTMAS STAMPS', 20, Decimal('1.25')),
#  (524134, '22734', 'SET OF 6 RIBBONS VINTAGE CHRISTMAS', 6, Decimal('2.55')),
#  (524134, '84347', 'ROTATING SILVER ANGELS T-LIGHT HLDR', 24, Decimal('2.55')),
#  (524134, '22174', 'PHOTO CUBE', 48, Decimal('1.48')),
#  (524134, '22423', 'REGENCY CAKESTAND 3 TIER', 2, Decimal('12.75')),
#  (524134, '22585', 'PACK OF 6 BIRDY GIFT TAGS', 12, Decimal('1.25')),
#  (524134, '84946', 'ANTIQUE SILVER TEA GLASS ETCHED', 36, Decimal('1.25')),
#  (524134, '22178', 'VICTORIAN GLASS HANGING T-LIGHT', 12, Decimal('1.25')),
#  (524134, '21495', 'SKULLS AND CROSSBONES WRAP', 25, Decimal('0.42')),
#  (524134, '22045', 'SPACEBOY GIFT WRAP', 25, Decimal('0.42')),
#  (524134, '21499', 'BLUE SPOTS  WRAP', 25, Decimal('0.42')),
#  (524134, '21498', 'RED SPOTS  WRAP ', 25, Decimal('0.42')),
#  (524134, '21500', 'PINK SPOTS  WRAP ', 25, Decimal('0.42')),
#  (524134, '22704', 'WRAP RED APPLES ', 25, Decimal('0.42')),
#  (524134, '22705', 'WRAP GREEN PEARS ', 25, Decimal('0.42')),
#  (524134, '22046', 'TEA PARTY  WRAPPING PAPER ', 25, Decimal('0.42')),
#  (524139, '22423', 'REGENCY CAKESTAND 3 TIER', 16, Decimal('10.95')),
#  (524139, '85123A', 'WHITE HANGING HEART T-LIGHT HOLDER', 32, Decimal('2.55')),
#  (524139, '22121', 'NOEL WOODEN BLOCK LETTERS ', 3, Decimal('5.95')),
#  (524139, '22187', 'GREEN CHRISTMAS TREE CARD HOLDER', 4, Decimal('4.25')),
#  (524139, '22044', 'CHRISTMAS CARD STACK OF PRESENTS', 12, Decimal('0.42')),
#  (524139, '22816', 'CARD MOTORBIKE SANTA', 12, Decimal('0.42')),
#  (524139, '22152', 'PLACE SETTING WHITE STAR', 24, Decimal('0.42')),
#  (524139, '22151', 'PLACE SETTING WHITE HEART', 24, Decimal('0.42')),
#  (524139, '21773', 'DECORATIVE ROSE BATHROOM BOTTLE', 12, Decimal('1.25')),
#  ...]

# %%
cursor.description
# Out:
# (Column(name='invoice_id', type_code=23),
#  Column(name='stock_code', type_code=1043),
#  Column(name='description', type_code=1043),
#  Column(name='quantity', type_code=23),
#  Column(name='price', type_code=1700))

# %%
columns = []                     # В этот список будем сохранять названия колонок
for desc in cursor.description:  
    columns.append(desc[0])      # Названия колонок возьмем из первого элемента cursor.description

    
products = pd.DataFrame(result, columns=columns)  # Из списка кортежей сделаем датафрейм
products.head()
# Out:
#    invoice_id stock_code                     description  quantity price
# 0      524025      21232  STRAWBERRY CERAMIC TRINKET BOX        72  1.06
# 1      524025     85099C  JUMBO  BAG BAROQUE BLACK WHITE       100  1.65
# 2      524025      21231  SWEETHEART CERAMIC TRINKET BOX        72  1.06
# 3      524025     47570B            TEA TIME TABLE CLOTH        50  8.49
# 4      524025      20685           DOORMAT RED RETROSPOT        10  6.75

# %%
products['invoice_id'] = products['invoice_id'].apply(str)
products['stock_code'] = products['stock_code'].apply(str)
products['description'] = products['description'].apply(str)
products['quantity'] = products['quantity'].apply(int)
products['price'] = products['price'].apply(float)

# %% [markdown]
# ## Задание 2
#
# __Посчитайте, какой доход принес каждый продукт и сколько единиц каждого продукта было продано__
#
# 1. Посчитай общую сумму оплат для каждой строки счета
# 2. Получи общий доход и количество единиц по товарам
# 3. Объедини сгруппированные данные в один датафрейм со столбцами: `description`, `stock_code`, `quantity`, `total`

# %%
products['total'] = products['quantity'] * products['price']
products.head()
# Out:
#   invoice_id stock_code                     description  quantity  price  \
# 0     524025      21232  STRAWBERRY CERAMIC TRINKET BOX        72   1.06
# 1     524025     85099C  JUMBO  BAG BAROQUE BLACK WHITE       100   1.65
# 2     524025      21231  SWEETHEART CERAMIC TRINKET BOX        72   1.06
# 3     524025     47570B            TEA TIME TABLE CLOTH        50   8.49
# 4     524025      20685           DOORMAT RED RETROSPOT        10   6.75
#
#     total
# 0   76.32
# 1  165.00
# 2   76.32
# 3  424.50
# 4   67.50

# %%
# посчитай общих доход по каждому товару
total_stock = products.groupby('stock_code')['total'].sum().reset_index()
total_stock.head()
# Out:
#   stock_code    total
# 0      10002  6638.27
# 1      10080   124.61
# 2      10109     1.68
# 3      10120   136.08
# 4     10123C   226.76

# %%
# посчитай общее количество проданных единиц по каждому товару
quantity_stock = products.groupby('stock_code')['quantity'].sum().reset_index()
quantity_stock.head()
# Out:
#   stock_code  quantity
# 0      10002      8479
# 1      10080       303
# 2      10109         4
# 3      10120       648
# 4     10123C       628

# %%
# объедини общие данные в одну таблицу
qua_tot = pd.merge(total_stock, quantity_stock, on='stock_code')
qua_tot.head()
# Out:
#   stock_code    total  quantity
# 0      10002  6638.27      8479
# 1      10080   124.61       303
# 2      10109     1.68         4
# 3      10120   136.08       648
# 4     10123C   226.76       628

# %% [markdown]
# ## Задание 3
#
# __Найди нарастающий итог по процентам__
#
# 1. Отсортируй датафрейм по доходу в нисходящем порядке
# 2. Найди процент дохода каждого товара в общем доходе
# 3. Сделай нарастающий итог (running total) по процентам каждого товара, для этого найди в интернете и примени метод для расчета кумулятивной суммы в `pandas`.
#
#
# Нарастающий итог — это представление данных, в котором мы видим динамику нарастания или убывания суммы от начала отсчета до конца. Получаем мы эту кумулятивную сумму, прибавлением поочередно каждого следующего элемента к сумме предыдущих.

# %%
# отсортируй дата-фрейм (большие вверху, маленькие внизу)
sorted_qua_tot = qua_tot.sort_values(by='total' , ascending=False)
sorted_qua_tot.head()
# Out:
#      stock_code      total  quantity
# 1609      22423  277656.25     24139
# 4080     85123A  247203.36     91814
# 2726      23843  168469.60     80995
# 4058     85099B  167920.64     93436
# 4625          M  151777.67      9391

# %%
# найди процент дохода для каждого товара 

#(искомая часть / целое число) * 100

sorted_qua_tot['per_revenue'] = sorted_qua_tot['total'] / sorted_qua_tot['total'].sum() *100
sorted_qua_tot
# Out:
#      stock_code      total  quantity  per_revenue
# 1609      22423  277656.25     24139     1.598040
# 4080     85123A  247203.36     91814     1.422769
# 2726      23843  168469.60     80995     0.969620
# 4058     85099B  167920.64     93436     0.966461
# 4625          M  151777.67      9391     0.873550
# ...         ...        ...       ...          ...
# 4630    TEST002       1.00         1     0.000006
# 247       20721       0.85         1     0.000005
# 3419     84205C       0.38         2     0.000002
# 2847      35930       0.38         1     0.000002
# 4626       PADS       0.00        18     0.000000
#
# [4631 rows x 4 columns]

# %%
# используй метод pandas для кумулятивной суммы
running_total = pd.DataFrame(sorted_qua_tot.groupby('stock_code')['per_revenue'].sum()).sort_values(by='per_revenue' , ascending=False).reset_index()
running_total['cum_sum'] = running_total['per_revenue'].cumsum()

running_total
# Out:
#      stock_code  per_revenue     cum_sum
# 0         22423     1.598040    1.598040
# 1        85123A     1.422769    3.020809
# 2         23843     0.969620    3.990429
# 3        85099B     0.966461    4.956890
# 4             M     0.873550    5.830440
# ...         ...          ...         ...
# 4626    TEST002     0.000006   99.999991
# 4627      20721     0.000005   99.999996
# 4628     84205C     0.000002   99.999998
# 4629      35930     0.000002  100.000000
# 4630       PADS     0.000000  100.000000
#
# [4631 rows x 3 columns]

# %% [markdown]
# ## Задание 4
#
# __Пометь товары метками `'A'`, `'B'`, `'C'` в зависимости от нарастающего итога__
#
# 1. Напиши функцию, которая будет помечать товары с нарастающим итогом ниже или равно 80% как группу `'A'`, от 80%-95% — как `'B'` и остальные как `'C'`

# %%
def revenue(x):

    if x <= 80:
        return 'A'
    elif x > 80 and x <= 95:
        return 'B'
    else:
        return 'C'    # допиши функцию

# создай новый столбец revenue с помощью функции
running_total['revenue'] = running_total['cum_sum'].apply(revenue) 
running_total
# Out:
#      stock_code  per_revenue     cum_sum revenue
# 0         22423     1.598040    1.598040       A
# 1        85123A     1.422769    3.020809       A
# 2         23843     0.969620    3.990429       A
# 3        85099B     0.966461    4.956890       A
# 4             M     0.873550    5.830440       A
# ...         ...          ...         ...     ...
# 4626    TEST002     0.000006   99.999991       C
# 4627      20721     0.000005   99.999996       C
# 4628     84205C     0.000002   99.999998       C
# 4629      35930     0.000002  100.000000       C
# 4630       PADS     0.000000  100.000000       C
#
# [4631 rows x 4 columns]

# %% [markdown]
# ## Задание 5
#
# __Найди нарастающий итог по количеству товарных единиц и пометь товары метками `'A'`, `'B'`, `'C'`, отмечая тем самым популярность товара__
#
# 1. Отсортируй предыдущий датафрейм с данными о доходе теперь по количеству товаров
# 2. Найди процент каждого товара в общем количестве
# 3. Найди нарастающий итог по количеству
# 4. Напиши функцию с теми же параметрами, что и у дохода
# 5. Отметь группу

# %%
sorted_qua_tot = qua_tot.sort_values(by='quantity' , ascending=False)
sorted_qua_tot.head()
# Out:
#      stock_code      total  quantity
# 3410      84077   24098.03    105185
# 4058     85099B  167920.64     93436
# 4080     85123A  247203.36     91814
# 601       21212   43390.03     89850
# 2726      23843  168469.60     80995

# %%
# проведи те же операции, что в двух предыдущих заданиях, для оценки популярности товаров
sorted_qua_tot['per_quantity'] = sorted_qua_tot['quantity'] / sorted_qua_tot['quantity'].sum() *100
sorted_qua_tot
# Out:
#      stock_code      total  quantity  per_quantity
# 3410      84077   24098.03    105185      0.999031
# 4058     85099B  167920.64     93436      0.887441
# 4080     85123A  247203.36     91814      0.872035
# 601       21212   43390.03     89850      0.853381
# 2726      23843  168469.60     80995      0.769278
# ...         ...        ...       ...           ...
# 2936      37484       6.75         1      0.000009
# 4144      85171       2.55         1      0.000009
# 2917      37451       4.95         1      0.000009
# 2907      37438       3.75         1      0.000009
# 4630    TEST002       1.00         1      0.000009
#
# [4631 rows x 4 columns]

# %%
running_quantity = pd.DataFrame(sorted_qua_tot.groupby('stock_code')['per_quantity'].sum()).sort_values(by='per_quantity' , ascending=False).reset_index()
running_quantity['cum_sum_qua'] = running_quantity['per_quantity'].cumsum()

running_quantity
# Out:
#      stock_code  per_quantity  cum_sum_qua
# 0         84077      0.999031     0.999031
# 1        85099B      0.887441     1.886471
# 2        85123A      0.872035     2.758506
# 3         21212      0.853381     3.611888
# 4         23843      0.769278     4.381166
# ...         ...           ...          ...
# 4626      37484      0.000009    99.999962
# 4627      85171      0.000009    99.999972
# 4628      37451      0.000009    99.999981
# 4629      37438      0.000009    99.999991
# 4630    TEST002      0.000009   100.000000
#
# [4631 rows x 3 columns]

# %%
def quantity(x):

    if x <= 80:
        return 'A'
    elif x > 80 and x <= 95:
        return 'B'
    else:
        return 'C'   # допиши функцию

# создай новый столбец popularity с помощью функции
running_quantity['popularity'] = running_quantity['cum_sum_qua'].apply(quantity) 
running_quantity
# Out:
#      stock_code  per_quantity  cum_sum_qua popularity
# 0         84077      0.999031     0.999031          A
# 1        85099B      0.887441     1.886471          A
# 2        85123A      0.872035     2.758506          A
# 3         21212      0.853381     3.611888          A
# 4         23843      0.769278     4.381166          A
# ...         ...           ...          ...        ...
# 4626      37484      0.000009    99.999962          C
# 4627      85171      0.000009    99.999972          C
# 4628      37451      0.000009    99.999981          C
# 4629      37438      0.000009    99.999991          C
# 4630    TEST002      0.000009   100.000000          C
#
# [4631 rows x 4 columns]

# %%
prod = pd.merge(running_total,running_quantity,on='stock_code').reset_index()
prod = prod[['stock_code','revenue','popularity']]
prod
# Out:
#      stock_code revenue popularity
# 0         22423       A          A
# 1        85123A       A          A
# 2         23843       A          A
# 3        85099B       A          A
# 4             M       A          A
# ...         ...     ...        ...
# 4626    TEST002       C          C
# 4627      20721       C          C
# 4628     84205C       C          C
# 4629      35930       C          C
# 4630       PADS       C          C
#
# [4631 rows x 3 columns]

# %% [markdown]
# ## Задание 6
#
# __Объедини группы и проанализируй__
#
# 1. Создай серию `group` с объединенным столбцом отметок популярности и доходности товаров
# 2. Посчитай количество вхождений каждой сгруппированной пары
# 3. Какие группы непопулярны и приносят мало дохода?
# 4. На каких группах товаров нужно сфокусироваться при составлении плана закупок?

# %%
# напиши здесь код и комментарии
prod['group']=prod['revenue'] + prod['popularity']

prod.head()
# Out:
#   stock_code revenue popularity group
# 0      22423       A          A    AA
# 1     85123A       A          A    AA
# 2      23843       A          A    AA
# 3     85099B       A          A    AA
# 4          M       A          A    AA

# %%
prod['group'].value_counts()
# Out:
# CC    2041
# AA     685
# BB     577
# BC     377
# CB     303
# BA     270
# AB     248
# CA      72
# AC      58
# Name: group, dtype: int64

# %% [markdown]
# Hепопулярны и приносят мало дохода группы BC, CB и CC.
# При составлении плана закупок нужно сфокусироваться на группах товаров AA, AB и BA.

# %% [markdown]
# ## Задание 7
#
# __Выгрузи данные по товарам с метокой по ABC-анализу__
#
# 1. Объедини по `stock_code` в одной таблице `ABC-код`, описание товара и `ID `
#
# 2. Выгрузи таблицу в `csv` для отправки в отдел закупок

# %%
prodABC = pd.merge(products, prod, on='stock_code' , how='inner')
#prodABC = [['stock_code', 'group','description','invoice_id']]
prodABC
# Out:
#        invoice_id stock_code                          description  quantity  \
# 0          524025      21232       STRAWBERRY CERAMIC TRINKET BOX        72
# 1          524091      21232       STRAWBERRY CERAMIC TRINKET BOX        12
# 2          524099      21232       STRAWBERRY CERAMIC TRINKET BOX        12
# 3          524184      21232       STRAWBERRY CERAMIC TRINKET BOX         3
# 4          524206      21232       STRAWBERRY CERAMIC TRINKET BOX        12
# ...           ...        ...                                  ...       ...
# 779490     513566    ADJUST2  Adjustment by Peter on Jun 25 2010          1
# 779491     513565    ADJUST2  Adjustment by Peter on Jun 25 2010          1
# 779492     515916      45014                   FOLDING SHIRT TIDY         1
# 779493     517719      21585           SWALLOW SMALL TUBE MATCHES         1
# 779494     521362      78026         SEAGRASS S/3 SQU LAUNDRY BOX        11
#
#          price   total revenue popularity group
# 0         1.06   76.32       A          A    AA
# 1         1.25   15.00       A          A    AA
# 2         1.25   15.00       A          A    AA
# 3         1.25    3.75       A          A    AA
# 4         1.25   15.00       A          A    AA
# ...        ...     ...     ...        ...   ...
# 779490  358.47  358.47       C          C    CC
# 779491   72.45   72.45       C          C    CC
# 779492    4.65    4.65       C          C    CC
# 779493    1.65    1.65       C          C    CC
# 779494   10.00  110.00       C          C    CC
#
# [779495 rows x 9 columns]

# %%
prod_ABC = prodABC [['stock_code', 'group','description','invoice_id']]
prod_ABC.head()
# Out:
#   stock_code group                     description invoice_id
# 0      21232    AA  STRAWBERRY CERAMIC TRINKET BOX     524025
# 1      21232    AA  STRAWBERRY CERAMIC TRINKET BOX     524091
# 2      21232    AA  STRAWBERRY CERAMIC TRINKET BOX     524099
# 3      21232    AA  STRAWBERRY CERAMIC TRINKET BOX     524184
# 4      21232    AA  STRAWBERRY CERAMIC TRINKET BOX     524206

# %%
prod_ABC.to_csv('prod_ABC.csv', index=False)

# %% [markdown]
# # 🎉🎉🎉 Поздравляем, ты великолепен!
